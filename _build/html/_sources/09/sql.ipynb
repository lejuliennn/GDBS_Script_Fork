# %% [markdown]
# # SQL

# %%
import sqlite3
# %load_ext sql
# %sql sqlite:///filme/filme.db
# %sql sqlite:///salesDB/salesDB
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
__SQL__ = " SELECT * FROM Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out 2015 95 TRUE Disney 1234
# Toy Story 1999 81 TRUE Disney 1234
# Up 2009 96 TRUE Pixar 4567
# Ratatouille 2007 111 TRUE Pixar 4567
# Star Wars 1977 121 TRUE Pinewood 78910
# Star Trek 1979 132 TRUE Paramount  6789
# Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Into the Wild 2007 148 TRUE Paramount  6789
# Brokeback Mountain 2005 134 TRUE River Road 4712
# The Lighthouse 2019 109 FALSE A24 1748
# Roma 2018 135 FALSE Participant 5123
# La Heine 1995 98 FALSE NULL 2212
# Total Recall 1990 113 TRUE Fox 3310
# Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Pulp Fiction 1994 154 TRUE A Band Apart 7654
# The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# La La Land 2016 128 TRUE Summit Entertainment 5123
# Moonlight 2016 124 TRUE A24 1748
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# House of Gucci 2021 158 TRUE MGM 5555
# James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Shipwrecked 1990 92 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234

# %% [markdown]
# ## Einführung
# ### SQL-Historie
# ■ SEQUEL (1974, IBM Research Labs San Jose)
# <br><br>
# ■ SEQUEL2 (1976, IBM Research Labs San Jose)
# <br>
# □ System R
# <br><br>
# ■ SQL (1982, IBM)
# <br><br>
# ![title](historie1.jpg)
# <br>
# ![title](historie2.jpg)
# <br>
# ![title](historie3.jpg)
# ### SQL – Standardisierung
# ■ SQL1 von ANSI als Standard verabschiedet (1986)
#  <br>
#  <br>
# ■ SQL1 von der (ISO) als Standard verabschiedet (1987)
#  <br>
# □ 1989 nochmals überarbeitet.
#  <br> <br>
# ■ SQL2 oder SQL-92 von der ISO verabschiedet (1992)
#  <br> <br>
# ■ SQL3 oder SQL:1999 verabschiedet
#  <br>
# □ Trigger, rekursive Anfragen
#  <br>
# □ Objektrelationale Erweiterungen
#  <br> <br>
# ■ SQL:2003 von der ISO verabschiedet
#  <br>
# □ XML-Support durch SQL/XML
#  <br> <br>
# ■ SQL/XML:2006
#  <br>
# □ XQuery eingebunden
#  <br> <br>
# ■ SQL:2008
#  <br>
# □ Updates auf Sichten, logisches Löschen (TRUNCATE), …
#  <br> <br>
# ■ SQL:2011
#  <br>
# □ Adds temporal data (PERIOD FOR)
#  <br> <br>
# ■ SQL:2016
#  <br>
# □ Adds row pattern matching, polymorphic table functions, JSON.
# <br><br>
# Trotz Standardisierung: Inkompatibilitäten zwischen Systemen der einzelnen Hersteller
# ### SQL:2008 Struktur
# ■ Part 1: Framework (SQL/Framework) – 82 Seiten
# <br>
# □ Überblick
# <br><br>
# ■ Part 2: Foundation (SQL/Foundation) – 1316 Seiten
# <br>
# □ Datenmodell, DDL, DML, Abfragen
# <br><br>
# ■ Part 3: Call-Level Interface (SQL/CLI) – 389 Seiten
# <br>
# □ Zugriff auf DBMS mittels Funktionsaufrufen aus anderen Programmiersprachen
# <br><br>
# ■ Part 4: Persistent Stored Modules (SQL/PSM) – 188 Seiten
# <br>
# □ Prozedurale Erweiterungen
# <br><br>
# ■ Part 9: Management of External Data (SQL/MED) – 484 Seiten
# <br>
# □ Neue Datentypen und Funktionen
# <br><br>
# ■ Part 10: Object Language Bindings (SQL/OLB) – 396 Seiten
# <br>
# □ Auch (SQLJ); zur Einbettung von SQL in Java
# <br><br>
# ■ Part 11: Information and Definition Schemas (SQL/Schemata) – 286 Seiten
# <br>
# □ DBMS werden selbst-beschreibend durch normierten Katalog
# <br><br>
# ■ Part 13: SQL Routines and Types (SQL/JRT) – 198 Seiten
# <br>
# □ Externe Java Routinen als „stored procedures“
# <br><br>
# ■ Part 14: XML-Related Specifications (SQL/XML) – 438 Seiten
# <br>
# □ XML Datentyp und Erweiterung von SQL um XQuery
# <br><br>
# => Zusammen: 3777 Seiten
# ### Motivation für SQL
# ■ Meist-verbreitete Datenbankanfragesprache
# <br><br>
# ■ Ad-hoc und einfach
# <br><br>
# ■ Deklarativ
# <br>
# □ Nicht prozedural / imperativ
# <br>
# □ Optimierbar
# <br><br>
# ■ Very-High-Level Language
# <br><br>
# ■ Anfragen an relationale Algebra angelehnt
# <br>
# □ Hinzu kommt DDL: Data definition language
# <br>
# □ Hinzu kommt DML: Data manipulation language
# <br><br>
# ■ Achtung: Syntax kann sich von System zu System leicht unterscheiden.
# <br><br>
# ■ Achtung: Funktionalität kann sich von System zu System leicht unterscheiden.

# %% [markdown]
# ## Einfach Anfragen

# %% [markdown]
# ### Beispielschema
# ![title](beispielschema.jpg)
# ### SELECT … FROM … WHERE …

# %%
#SELECT * 
#FROM Film 
#WHERE StudioName = "Disney" AND Jahr= 1990;

__SQL__ = "SELECT * FROM Film WHERE StudioName = 'Disney' AND Jahr= 1990"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Shipwrecked 1990 92 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234

# %% [markdown]
# ■ Lesereihenfolge (und Schreibreihenfolge):
# <br>
# 1. FROM: Relation(en) aus denen die Daten stammen
# <br>
# 2. WHERE: Bedingung(en) an die Daten
# <br>
# 3. SELECT: Schema der Ergebnisrelation
# <br>
# – *: Alle Attribute der Inputrelationen
# <br><br>
# ■ Ausführung
# <br>
# □ Für jedes Tupel aus „Film“ prüfe die Bedingungen und gebe gültige Tupel aus
# ### Groß- und Kleinschreibung
# ■ In SQL wird Groß- und Kleinschreibung nicht beachtet
# <br>
#
# ```
# From = FROM = from = FrOm
# ```
#
# <br><br>
# ■ Auch bei Attribut- und Relationennamen
# <br>
#
# ```
# SELect vorNAMe fROm fiLM
# ```
# <br>
#
#
# ```
# SELECT vorname FROM film
# ```
# <br><br>
# ■ Natürlich nicht bei Konstanten:
# <br>
#
# ```
# ‘FROM‘ ≠ ‘from‘ ≠ from = FROM
# ```
# <br><br>
# ■ Konvention zur Lesbarkeit
# <br>
# □ Schlüsselworte großschreiben
# <br>
# □ Schemaelemente kleinschreiben
# ### Projektion in SQL (SELECT, $\pi$)
# ■ Spezifikation in der SELECT Klausel

# %%
#SELECT * 
#FROM Film

__SQL__ = " SELECT * FROM Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out 2015 95 TRUE Disney 1234
# Toy Story 1999 81 TRUE Disney 1234
# Up 2009 96 TRUE Pixar 4567
# Ratatouille 2007 111 TRUE Pixar 4567
# Star Wars 1977 121 TRUE Pinewood 78910
# Star Trek 1979 132 TRUE Paramount  6789
# Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Into the Wild 2007 148 TRUE Paramount  6789
# Brokeback Mountain 2005 134 TRUE River Road 4712
# The Lighthouse 2019 109 FALSE A24 1748
# Roma 2018 135 FALSE Participant 5123
# La Heine 1995 98 FALSE NULL 2212
# Total Recall 1990 113 TRUE Fox 3310
# Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Pulp Fiction 1994 154 TRUE A Band Apart 7654
# The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# La La Land 2016 128 TRUE Summit Entertainment 5123
# Moonlight 2016 124 TRUE A24 1748
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# House of Gucci 2021 158 TRUE MGM 5555
# James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Shipwrecked 1990 92 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234

# %% [markdown]
# – Alle Attribute

# %%
#SELECT Titel, Jahr, inFarbe 
#FROM Film

__SQL__ = "SELECT Titel, Jahr, inFarbe FROM Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out 2015 TRUE
# Toy Story 1999 TRUE
# Up 2009 TRUE
# Ratatouille 2007 TRUE
# Star Wars 1977 TRUE
# Star Trek 1979 TRUE
# Lady Bird 2017 TRUE
# Into the Wild 2007 TRUE
# Brokeback Mountain 2005 TRUE
# The Lighthouse 2019 FALSE
# Roma 2018 FALSE
# La Heine 1995 FALSE
# Total Recall 1990 TRUE
# Mamma Mia! 2008 TRUE
# The Dark Knight 2008 TRUE
# Pulp Fiction 1994 TRUE
# The Great Gatsby 2013 TRUE
# Spider-Man 2002 TRUE
# La La Land 2016 TRUE
# Moonlight 2016 TRUE
# Ducktales the Movie: Treasure of the Lost Lamp 1990 TRUE
# House of Gucci 2021 TRUE
# James Bond 007: Spectre 2015 TRUE
# Shipwrecked 1990 TRUE
# The Rescuers Down Under 1990 TRUE

# %% [markdown]
# – Projektion auf die drei Attribute
# <br><br>
# ■ Erweiterte Projektion
# <br>
# □ Umbenennung:

# %%
#SELECT Titel AS Name, Jahr AS Zeit 
#FROM Film

__SQL__ = "SELECT Titel AS Name, Jahr AS Zeit FROM Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out 2015
# Toy Story 1999
# Up 2009
# Ratatouille 2007
# Star Wars 1977
# Star Trek 1979
# Lady Bird 2017
# Into the Wild 2007
# Brokeback Mountain 2005
# The Lighthouse 2019
# Roma 2018
# La Heine 1995
# Total Recall 1990
# Mamma Mia! 2008
# The Dark Knight 2008
# Pulp Fiction 1994
# The Great Gatsby 2013
# Spider-Man 2002
# La La Land 2016
# Moonlight 2016
# Ducktales the Movie: Treasure of the Lost Lamp 1990
# House of Gucci 2021
# James Bond 007: Spectre 2015
# Shipwrecked 1990
# The Rescuers Down Under 1990

# %% [markdown]
# □ Arithmetischer Ausdruck:

# %%
#SELECT Titel, Laenge * 0.016667 AS Stunden 
#FROM Film

__SQL__ = "SELECT Titel, Laenge * 0.016667 AS Stunden FROM Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out 1.5833650000000001
# Toy Story 1.350027
# Up 1.6000320000000001
# Ratatouille 1.8500370000000002
# Star Wars 2.0167070000000002
# Star Trek 2.200044
# Lady Bird 1.5833650000000001
# Into the Wild 2.4667160000000004
# Brokeback Mountain 2.233378
# The Lighthouse 1.8167030000000002
# Roma 2.250045
# La Heine 1.633366
# Total Recall 1.8833710000000001
# Mamma Mia! 1.8000360000000002
# The Dark Knight 2.5333840000000003
# Pulp Fiction 2.5667180000000003
# The Great Gatsby 2.366714
# Spider-Man 2.0167070000000002
# La La Land 2.133376
# Moonlight 2.066708
# Ducktales the Movie: Treasure of the Lost Lamp 1.2333580000000002
# House of Gucci 2.6333860000000002
# James Bond 007: Spectre 2.4667160000000004
# Shipwrecked 1.5333640000000002
# The Rescuers Down Under 1.2833590000000001

# %% [markdown]
# □ Konstanten:

# %%
#SELECT Titel, Laenge * 0.016667 AS Stunden, ‘std.‘ AS inStunden FROM Film

__SQL__ = "SELECT Titel, Laenge * 0.016667 AS Stunden, ‘std.‘ AS inStunden FROM Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
#   Input In [17]
#     ‘std.‘ AS inStunden FROM Film
#     ^
# SyntaxError: invalid character '‘' (U+2018)

# %% [markdown]
# ### Selektion in SQL (WHERE, $\sigma$)
# ■ Spezifikation in der WHERE Klausel
# <br>
# □ Bedingungen wie in einer Programmiersprache
# <br>
# □ Sechs Vergleichsoperatoren
# <br>
# – =, <>, <, >, <=, >=
# <br>
# – <>, <=, >= entspricht ≠, $\geq, \leq$
# <br>
# □ Operanden
# <br>
# – Konstanten und Attributnamen
# <br>
# – Auch Attribute, die nicht in der SELECT Klausel genannt werden.
# <br>
# □ Arithmetische Ausdrücke für numerische Attribute
# <br>
# – Z.B.:
# ```
# (Jahr - 1930) * (Jahr - 1930) <= 100
# ```
# □ Konkatenation für Strings
# ```
# ‘Star‘ || ‘Wars‘
# ```
# entspricht
# ```
# ‘StarWars‘
# ```
# – Vorname || \` \` || Nachname = \`Luke Skywalker\`
#
# ### Selektion in SQL
#
# ■ Ergebnis ist stets Boole‘scher Wert
# <br>
# □ TRUE oder FALSE
# <br>
# □ Können mit AND, OR und NOT verknüpft werden.
# <br>
# – Klammerungen sind erlaubt.
# <br>
# □ Nur wenn insgesamt auf TRUE evaluiert wird, erscheint das entsprechende Tupel im Ergebnis.
# <br>
# <br>
# ■ Beispiele

# %%
#SELECT Titel 
#FROM Film 
#WHERE Jahr > 1970 AND NOT inFarbe;

__SQL__ = "SELECT Titel FROM Film WHERE Jahr > 1970 AND NOT inFarbe"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out
# Toy Story
# Up
# Ratatouille
# Star Wars
# Star Trek
# Lady Bird
# Into the Wild
# Brokeback Mountain
# The Lighthouse
# Roma
# La Heine
# Total Recall
# Mamma Mia!
# The Dark Knight
# Pulp Fiction
# The Great Gatsby
# Spider-Man
# La La Land
# Moonlight
# Ducktales the Movie: Treasure of the Lost Lamp
# House of Gucci
# James Bond 007: Spectre
# Shipwrecked
# The Rescuers Down Under

# %%
#SELECT Titel 
#FROM Film 
#WHERE (Jahr > 1970 OR Laenge < 90) AND StudioName = "MGM";

__SQL__ = "SELECT Titel FROM Film WHERE (Jahr > 1970 OR Laenge < 90) AND StudioName = 'MGM';"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# House of Gucci
# James Bond 007: Spectre

# %% [markdown]
# ### Stringvergleiche
# ■ Datentypen
# <br>
# □ Array fester Länge, Buchstabenliste variabler Länge, Konstanten
# <br>
# □ SQL erlaubt viele Vergleiche über Datentypen hinweg
# <br><br>
# ■ foo _ _ _ _ _ = foo = ‘foo‘
# <br><br>
# ■ Vergleiche mit =, <, >, <=, >=, <>
# <br>
# □ Lexikographischer Vergleich
# <br>
# □ ‘fodder‘ < ‘foo‘; ‘bar‘ < ‘bargain‘;
# <br>
# □ Sortierreihenfolge upper-case/lower-case usw. je nach DBMS
# <br>
# □ Achtung: Auch nicht immer identisch zur Reihenfolge in Programmiersprachen
#
# ### String-Mustervergleiche mit LIKE
# ■ string LIKE pattern
# <br>
# □ bzw. string NOT LIKE pattern
# <br><br>
# ■ Pattern hat spezielle Zeichen
# <br>
# □ ‘%‘: Beliebige Sequenz von 0 oder mehr Zeichen
# <br>
# □ ‘_‘: Ein beliebiges Zeichen
# <br><br>

# %%
#SELECT Titel 
#FROM Film WHERE Titel LIKE "Star ____";

__SQL__ = "SELECT Titel FROM Film WHERE Titel LIKE 'Star ____'"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Star Trek
# Star Wars

# %% [markdown]
# □ Star Wars und Star Trek

# %%
#SELECT Titel 
#FROM Film 
#WHERE Titel LIKE "%War%";

__SQL__ = "SELECT Titel FROM Film WHERE Titel LIKE '%War%'"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Star Wars

# %% [markdown]
# ### Datum und Uhrzeit
# ■ Spezielle Datentypen und Repräsentationen
# <br>
# □ Datumskonstante:
# <br>
# – DATE ‘YYYY-MM-DD‘
# <br>
# – DATE ‘1948-05-14‘
# <br><br>
# □ Zeitkonstante
# <br>
# – TIME ‘HH:MM:SS.S‘
# <br>
# – TIME ‘15:00:02.5‘
# <br><br>
# □ Zeitstempel
# <br>
# – TIMESTAMP ‘1948-05-14 15:00:02.5‘
# <br><br>
# □ Zeitvergleiche
# <br>
# – TIME ‘15:00:02.5‘ < TIME ‘15:02:02.5‘ ergibt TRUE
# <br>
# – Selektion: ERSCHEINUNGSTAG >= DATE ‘1949-11-12‘
# ### Nullwerte
# Darstellung: NULL bzw. ⊥
# <br>
# <br>
# Mögliche Interpretationen
# <br>
# Unbekannter Wert
# <br>
# -> Geburtstag einer/s Schauspieler*in
# <br>
# Wert unzulässig
# <br>
# -> Ehegatte eines unverheirateten Schauspielers
# <br>
# Wert unterdrückt
# <br>
# -> Geheime Telefonnummer
# <br>
# <br>
# Regeln für Umgang mit Nullwerten
# <br>
# Arithmetische Operationen mit NULL ergeben NULL
# <br>
# Vergleich mit NULL ergibt Wahrheitswert UNKNOWN
# <br>
# NULL ist keine Konstante, sondern erscheint nur als Attributwert
# <br><br>
# Beispiel (sei der Wert von x NULL):
# <br>
# x+3 ergibt NULL.
# <br>
# NULL+3 ist kein zulässiger Ausdruck.
# <br>
# x = 3 ergibt UNKNOWN.
# <br><br>
# Prüfen von Nullwerten in WHERE Klausel
# <br>
# Geburtstag IS NULL bzw. Geburtstag IS NOT NULL
# ### Wahrheitswerte
#
# |AND|true|unknown|false|
# |---|---|---|---|
# |**true**|true|unknown|false|
# |**unknown**|unknown|unknown|false|
# |**false**|false|false|false|
#
#
# ■ Rechenregeln
# <br>
# □ TRUE = 1
# <br>
# FALSE = 0
# <br>
# UNKNOWN = ½
# <br>
# □ AND: Minimum der beiden Werte
# <br>
# □ OR: Maximum der beiden Werte
# <br>
# □ NOT: 1 – Wert
# <br><br>
# □ Beispiel
# <br>
# – TRUE AND (FALSE OR NOT(UNKNOWN))
# <br>
# = MIN(1, MAX(0, (1 - ½ )))
# <br>
# = MIN(1, MAX(0, ½ )
# <br>
# = MIN(1, ½ ) = ½.
#
#
# |Titel|Jahr|Länge|inFarbe|Studio|ProduzentinID|
# |---|---|---|---|---|---|
# |Total|Recall|1990|NULL|True|Fox|12345|
#
#  Überraschendes Verhalten

# %%
#SELECT * 
#FROM Film 
#WHERE Laenge <= 90 
#OR Laenge > 90; --Laenge <= 90 == UNKNOWN und Länge > 90

__SQL__ = "SELECT * FROM Film WHERE Laenge <= 90 OR Laenge > 90; --Laenge <= 90 == UNKNOWN und Länge > 90"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Inside Out 2015 95 TRUE Disney 1234
# Toy Story 1999 81 TRUE Disney 1234
# Up 2009 96 TRUE Pixar 4567
# Ratatouille 2007 111 TRUE Pixar 4567
# Star Wars 1977 121 TRUE Pinewood 78910
# Star Trek 1979 132 TRUE Paramount  6789
# Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Into the Wild 2007 148 TRUE Paramount  6789
# Brokeback Mountain 2005 134 TRUE River Road 4712
# The Lighthouse 2019 109 FALSE A24 1748
# Roma 2018 135 FALSE Participant 5123
# La Heine 1995 98 FALSE NULL 2212
# Total Recall 1990 113 TRUE Fox 3310
# Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Pulp Fiction 1994 154 TRUE A Band Apart 7654
# The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# La La Land 2016 128 TRUE Summit Entertainment 5123
# Moonlight 2016 124 TRUE A24 1748
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# House of Gucci 2021 158 TRUE MGM 5555
# James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Shipwrecked 1990 92 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234

# %% [markdown]
# □ Tupel erscheint nicht im Ergebnis.
# <br><br>
# ■ Ausführungspriorität: NOT vor AND vor OR
#
# ### Sortierung
#
# ■ ORDER BY Klausel ans Ende der Anfrage
# <br>
# □ ORDER BY \<Attributliste\> DESC/ASC
# <br>
# □ ASC (aufsteigend) ist default
# <br>

# %%
#SELECT * 
#FROM Film 
#WHERE StudioName = "Disney" 
#AND Jahr = 1990 ORDER BY Laenge, Titel;

__SQL__ = "SELECT * FROM Film WHERE StudioName = 'Disney' AND Jahr = 1990 ORDER BY Laenge, Titel;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234
# Shipwrecked 1990 92 TRUE Disney 1234

# %%
#SELECT * 
#FROM Film 
#WHERE StudioName = "Disney" 
#AND Jahr = 1990 ORDER BY Laenge ASC, Titel DESC;

__SQL__ = "SELECT * FROM Film WHERE StudioName = 'Disney' AND Jahr = 1990 ORDER BY Laenge ASC, Titel DESC;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234
# Shipwrecked 1990 92 TRUE Disney 1234

# %% [markdown]
# ## Anfragen über mehrere Relationen
#
# ### Motivation
# ■ Hauptstärke der Relationalen Algebra ist die Kombination von Relationen
# <br><br>
# ■ Erst mit mehreren Relationen sind viele interessante Anfragen möglich.
# <br><br>
# ■ Nennung der beteiligten Relationen in der FROM Klausel
#
# ### Kreuzprodukt und Join
# ■ Film(Titel, Jahr, Länge, inFarbe, StudioName, ProduzentinID)
# <br>
# ■ Manager*in(Name, Adresse, ManagerinID, Gehalt)

# %%
#SELECT Name 
#FROM Film, ManagerIn 
#WHERE Titel = "Star Wars" 
#AND ProduzentinID = ManagerinID; 

__SQL__ = "SELECT Name FROM Film, ManagerIn WHERE Titel = 'Star Wars' AND ProduzentinID = ManagerinID"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Paul Golding

# %%
#SELECT Name 
#FROM Film, ManagerIn --Kreuzprodukt
#WHERE Titel = ‘Star Wars‘--Selektionsbedingung 
#AND ProduzentinID = ManagerinID; --Joinbedingung

# %% [markdown]
# ■ Semantik
# <br>
# □ Betrachte jedes Tupelpaar der Relationen Film und Manager.
# □ Wende Bedingung der WHERE Klausel auf jedes Tupelpaar an
# <br>
# □ Falls Bedingung erfüllt, produziere ein Ergebnistupel.
# <br><br>
# ■ Kreuzprodukt gefolgt von Selektion: Join
# <br><br>
# ■ Reihenfolge der WHERE Bedingungen egal

# %%
#SELECT Name 
#FROM Film, ManagerIn 
#WHERE Titel = "Star Wars" 
#AND ProduzentinID = ManagerinID; 

__SQL__ = "SELECT Name FROM Film, ManagerIn WHERE Titel = 'Star Wars' AND ProduzentinID = ManagerinID"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Paul Golding

# %% [markdown]
# ### Uneindeutige Attributnamen
# ■ SchauspielerIn(Name, Adresse, Geschlecht, Geburtstag)
# <br><br>
# ■ ManagerIn(Name, Adresse, ManagerinID, Gehalt)
# <br><br>
# ■ Bei gleichen Attributnamen aus mehreren beteiligten Relationen:
# <br>
# □ Relationenname als Präfix:

# %%
#SELECT SchauspielerIn.Name, ManagerIn.Name 
#FROM SchauspielerIn, ManagerIn 
#WHERE SchauspielerIn.Adresse = ManagerIn.Adresse;


__SQL__ = "SELECT SchauspielerIn.Name, ManagerIn.Name FROM SchauspielerIn, ManagerIn WHERE SchauspielerIn.Adresse = ManagerIn.Adresse;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [33], in <cell line: 7>()
#       5 conn = sqlite3.connect("filme/filme.db")
#       6 cur = conn.cursor()
# ----> 7 cur.execute(__SQL__)
#       8 rows = cur.fetchall()
#      10 for row in rows:
#
# OperationalError: no such column: SchauspielerIn.Name

# %% [markdown]
# □ Präfix ist auch erlaubt wenn Attributname eindeutig ist.
# <br>
# – Erleichtert das Lesen von SQL Anfragen
#
# ### Tupelvariablen
# ■ Zur eindeutigen Kennzeichnung von Tupeln beteiligter Relationen
# <br>
# □ „Alias“ einer Relation
# <br>
# □ Insbesondere: Bei der mehrfachen Verwendung einer Relation in einer Anfrage
# <br><br>
# ■ Gesucht: Schauspieler, die zusammen leben

# %%
#SELECT Star1.Name, Star2.Name 
#FROM SchauspielerIn Star1, SchauspielerIn Star2 
#WHERE Star1.Adresse = Star2.Adresse

__SQL__ = "SELECT Star1.Name, Star2.Name FROM SchauspielerIn Star1, SchauspielerIn Star2 WHERE Star1.Adresse = Star2.Adresse"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [35], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: no such column: Star1.Name

# %% [markdown]
# □ Äquivalent zu Schauspieler AS Star2
# <br><br>
# ■ Auch sinnvoll als abkürzenden Schreibweise

# %%
#SELECT S.Name, M.Name
#FROM SchauspielerIn S, ManagerIn M
#WHERE S.Adresse = M.Adresse;


__SQL__ = "SELECT S.Name, M.Name FROM SchauspielerIn S, ManagerIn M WHERE S.Adresse = M.Adresse;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()

# %% [markdown]
# ■ Ohne explizites Angeben einer Tupelvariablen wird der Relationenname als Tupelvariable verwendet.
#
# ### Tupelvariablen-Selfjoin
#
#
# |Name|Adresse|Geschlecht|Geburt|
# |---|---|---|---|
# |Carrie Fisher|123 Maple St., Hollywood|F|9/9/99|
# |Mark Hamill|456 Oak Rd., Brentwood|M|8/8/88|
# |Brad Pitt|123 Maple St., Hollywood|M|7/7/77|

# %%
#SELECT Star1.Name, Star2.Name
#FROM SchauspielerIn Star1, SchauspielerIn Star2
#WHERE Star1.Adresse = Star2.Adresse;

__SQL__ = "SELECT Star1.Name, Star2.Name FROM SchauspielerIn Star1, SchauspielerIn Star2 WHERE Star1.Adresse = Star2.Adresse;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [36], in <cell line: 9>()
#       7 conn = sqlite3.connect("filme/filme.db")
#       8 cur = conn.cursor()
# ----> 9 cur.execute(__SQL__)
#      10 rows = cur.fetchall()
#      12 for row in rows:
#
# OperationalError: no such column: Star1.Name

# %% [markdown]
# |Star1.Name|Star2.Name|
# |---|---|
# |Carrie Fisher|Carrie Fisher|
# |Carrie Fisher|Brad Pitt|
# |Brad Pitt|Carrie Fisher|
# |Brad Pitt|Brad Pitt|
# |Mark Hamill|Mark Hamill|

# %%
#SELECT Star1.Name, Star2.Name
#FROM SchauspielerIn Star1, SchauspielerIn Star2
#WHERE Star1.Adresse = Star2.Adresse
#AND Star1.Name <> Star2.Name;

__SQL__ = "SELECT Star1.Name, Star2.Name FROM SchauspielerIn Star1, SchauspielerIn Star2 WHERE Star1.Adresse = Star2.Adresse AND Star1.Name <> Star2.Name;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [37], in <cell line: 10>()
#       8 conn = sqlite3.connect("filme/filme.db")
#       9 cur = conn.cursor()
# ---> 10 cur.execute(__SQL__)
#      11 rows = cur.fetchall()
#      13 for row in rows:
#
# OperationalError: no such column: Star1.Name

# %% [markdown]
# |Star1.Name|Star2.Name|
# |---|---|
# |Carrie Fisher|Brad Pitt|
# |Brad Pitt|Carrie Fisher|

# %% [markdown]
# |Star1.Name|Star2.Name|
# |---|---|
# |Brad Pitt|Carrie Fisher|
#
# ### Interpretation von Anfragen
#
# ■ Drei Interpretationsvarianten für Anfragen mit mehreren Relationen
# <br>
# □ Nested Loops (geschachtelte Schleifen)
# <br>
# – Bei mehreren Tupelvariablen: Eine geschachtelte Schleife für jede Variable
# <br>
# □ Parallele Zuordnung
# <br>
# – Alle Kombinationen werden parallel bezüglich der Bedingungen geprüft.
# <br>
# □ Relationale Algebra
# <br>
# – Bilde Kreuzprodukt
# <br>
# – Wende Selektionsbedingungen auf jedes Resultat-Tupel an
# <br><br>
#
# ■ Gegeben drei Relationen: R(A), S(A) und T(A)
# <br><br>
# ■ Gesucht: R $\cap$ (S $\cup$ T) (= (R $\cap$ S) $\cup$ (R $\cap$ T) )

# %%
# %sql
SELECT R.A
FROM R, S, T
WHERE R.A = S.A
OR R.A = T.A;

# %%
# %sql
SELECT *
FROM
(
    (SELECT A FROM R)
     INTERSECT
    (SELECT * FROM
     (SELECT A FROM S)
      UNION
    (SELECT A FROM T)
    )
)

# %% [markdown]
# ■ Problemfall: T ist leer, hat also kein Tupel
# <br><br>
# ■ Vermeintliches Resultat: R $\cap$ S
# <br><br>
# ■ Tatsächliches Resultat: leere Menge
# <br>
# □ Ausführung als drei geschachtelte Schleifen
#
# ### Joins
# ![title](joins.jpg)
#
#  Man kann Joins auch auf andere Weise ausdrücken.
#  <br>
# □ Geschmacksfrage
#  <br>
# □ Film CROSS JOIN spielt_in
#  <br>
# – Kreuzprodukt
#  <br>
# – Doppelte Attributnamen werden mit Präfix der Relation aufgelöst

# %%
#Film JOIN spielt_in ON Titel = FilmTitel AND Jahr = FilmJahr

__SQL__ = "Film JOIN spielt_in ON Titel = FilmTitel AND Jahr = FilmJahr"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
#    sqlite:///filme/filme.db
#  * sqlite:///salesDB/salesDB.db
# (sqlite3.OperationalError) near "Film": syntax error
# [SQL: Film JOIN spielt_in ON Titel = FilmTitel AND Jahr = FilmJahr]
# (Background on this error at: http://sqlalche.me/e/e3q8)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [38], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "Film": syntax error

# %% [markdown]
# – Theta-Join

# %%
#SELECT Titel, Jahr, Laenge, inFarbe, StudioName, ProduzentinID, Name 
#FROM Film JOIN spielt_in ON Titel = FilmTitel 
#AND Jahr = FilmJahr;

__SQL__ = "SELECT Titel, Jahr, Laenge, inFarbe, StudioName, ProduzentinID, Name FROM Film JOIN spielt_in ON Titel = FilmTitel AND Jahr = FilmJahr;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Star Wars 1977 121 TRUE Pinewood 78910 Mark Hamill
# Star Wars 1977 121 TRUE Pinewood 78910 Harrison Ford
# Star Wars 1977 121 TRUE Pinewood 78910 Carrie Fisher
# Into the Wild 2007 148 TRUE Paramount  6789 Emile Hirsch
# Brokeback Mountain 2005 134 TRUE River Road 4712 Jake Gyllenhaal
# Brokeback Mountain 2005 134 TRUE River Road 4712 Heath Ledger
# The Dark Knight 2008 152 TRUE Warner Bros. 6035 Heath Ledger
# The Lighthouse 2019 109 FALSE A24 1748 Robert Pattinson
# The Lighthouse 2019 109 FALSE A24 1748 Willem Dafoe
# The Great Gatsby 2013 142 TRUE Village Roadshows  8634 Leonardo DiCaprio
# The Great Gatsby 2013 142 TRUE Village Roadshows  8634 Tobey Maguire
# The Great Gatsby 2013 142 TRUE Village Roadshows  8634 Carey Mulligan
# Lady Bird 2017 95 TRUE Scott Rudin Productions 3456 Saoirse Ronan
# La Heine 1995 98 FALSE NULL 2212 Vincent Cassel
# Mamma Mia! 2008 108 TRUE Littlestar Productions 8871 Meryl Streep
# Inside Out 2015 95 TRUE Disney 1234 Phyllis Smith
# Total Recall 1990 113 TRUE Fox 3310 Arnold Schwarzenegger
# Total Recall 1990 113 TRUE Fox 3310 Sharon Stone
# Pulp Fiction 1994 154 TRUE A Band Apart 7654 Samuel L. Jackson
# Up 2009 96 TRUE Pixar 4567 Tom Hanks
# Spider-Man 2002 121 TRUE Marvel Enterprises 6362 Tobey Maguire
# Spider-Man 2002 121 TRUE Marvel Enterprises 6362 Willem Dafoe
# Spider-Man 2002 121 TRUE Marvel Enterprises 6362 Kirsten Dunst
# La La Land 2016 128 TRUE Summit Entertainment 5123 Emma Stone
# La La Land 2016 128 TRUE Summit Entertainment 5123 Ryan Gosling
# Moonlight 2016 124 TRUE A24 1748 Mahershala Ali
# Star Trek 1979 132 TRUE Paramount  6789 William Shatner
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234 Alan Young
# House of Gucci 2021 158 TRUE MGM 5555 Jared Leto
# House of Gucci 2021 158 TRUE MGM 5555 Adam Driver
# House of Gucci 2021 158 TRUE MGM 5555 Lady Gaga
# James Bond 007: Spectre 2015 148 TRUE MGM 5555 Daniel Craig
# James Bond 007: Spectre 2015 148 TRUE MGM 5555 Léa Seydoux
# James Bond 007: Spectre 2015 148 TRUE MGM 5555 Christoph Waltz

# %% [markdown]
# – Eliminiert redundante Attribute FilmTitel und FilmJahr

# %%
#SELECT Titel, Jahr 
#FROM Film JOIN spielt_in ON Titel = FilmTitel 
#AND Jahr = FilmJahr JOIN SchauspielerIn ON spielt_in.Name = SchauspielerIn.Name 
#WHERE Geschlecht = "f";

__SQL__ = "SELECT Titel, Jahr FROM Film JOIN spielt_in ON Titel = FilmTitel AND Jahr = FilmJahr JOIN SchauspielerIn ON spielt_in.Name = SchauspielerIn.Name WHERE Geschlecht = 'f'"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [43], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: no such column: Geschlecht

# %% [markdown]
# □ Schauspieler NATURAL JOIN Manager
# <br>
# – Natural Join; Eliminiert redundante Attribute
#
# ### The TPC-H Schema
# ![title](tpc-h_schema.jpg)
#
# #### TPC Query 2 - Minimum Cost Supplier

# %%
# %sql
SELECT s_acctbal, s_name, n_name, p_partkey, p_mfgr, s_address, s_phone,
s_comment
FROM part, supplier, partsupp, nation, region
WHERE p_partkey = ps_partkey AND s_suppkey = ps_suppkey
AND p_size = [SIZE] AND p_type like '%[TYPE]'
AND s_nationkey = n_nationkey AND n_regionkey = r_regionkey
AND r_name = '[REGION]'
AND ps_supplycost =
(SELECT min(ps_supplycost)
FROM partsupp, supplier, nation, region
WHERE p_partkey = ps_partkey AND s_suppkey = ps_suppkey
AND s_nationkey = n_nationkey AND n_regionkey = r_regionkey
AND r_name = '[REGION]' )
ORDER BY s_acctbal desc, n_name, s_name, p_partkey;
# Out:
#   Input In [28]
#     SELECT s_acctbal, s_name, n_name, p_partkey, p_mfgr, s_address, s_phone,
#            ^
# SyntaxError: invalid syntax

# %%
SELECT s_acctbal, s_name, n_name, p_partkey, p_mfgr, s_address, s_phone, s_comment FROM part, supplier, partsupp, nation, region WHERE p_partkey = ps_partkey AND s_suppkey = ps_suppkey AND p_size = [SIZE] AND p_type like '%[TYPE]' AND s_nationkey = n_nationkey AND n_regionkey = r_regionkey AND r_name = '[REGION]' AND ps_supplycost = (SELECT min(ps_supplycost) FROM partsupp, supplier, nation, region WHERE p_partkey = ps_partkey AND s_suppkey = ps_suppkey AND s_nationkey = n_nationkey AND n_regionkey = r_regionkey AND r_name = '[REGION]' ) ORDER BY s_acctbal desc, n_name, s_name, p_partkey;

# %%
__SQL__ = "SELECT s_acctbal, s_name, n_name, p_partkey, p_mfgr, s_address, s_phone, s_comment FROM part, supplier, partsupp, nation, region WHERE p_partkey = ps_partkey AND s_suppkey = ps_suppkey AND p_size = [SIZE] AND p_type like '%[TYPE]' AND s_nationkey = n_nationkey AND n_regionkey = r_regionkey AND r_name = '[REGION]' AND ps_supplycost = (SELECT min(ps_supplycost) FROM partsupp, supplier, nation, region WHERE p_partkey = ps_partkey AND s_suppkey = ps_suppkey AND s_nationkey = n_nationkey AND n_regionkey = r_regionkey AND r_name = '[REGION]' ) ORDER BY s_acctbal desc, n_name, s_name, p_partkey;"
conn = sqlite3.connect("salesDB/salesDB")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       2 conn = sqlite3.connect("salesDB/salesDB")
#       3 cur = conn.cursor()
# ----> 4 cur.execute(__SQL__)
#       5 rows = cur.fetchall()
#       7 for row in rows:
#
# OperationalError: no such column: SIZE

# %% [markdown]
# SIZE is randomly selected within [1. 50];
# <br>
# TYPE is randomly selected within the list Syllable 3 defined for Types
# <br>
# REGION is randomly selected within the list of values defined for R_NAME
#
# #### The TPC-H Universal Table

# %%
# %sql
SELECT l_linenumber, l_quantity, l_extendedprice, l_discount, l_tax, l_returnflag, l_linestatus, l_shipdate, l_commitdate, l_receiptdate, l_shipinstruct, l_shipmode, l_comment, o_orderkey, o_orderstatus, o_totalprice, o_orderdate, o_orderpriority, o_clerk, o_shippriority, o_comment, ps_availqty, ps_supplycost, ps_comment, p_partkey, p_name, p_mfgr, p_brand, p_type, p_size, p_container, p_retailprice, p_comment, c_custkey, c_name, c_address, c_phone, c_acctbal, c_mktsegment, c_comment, s_suppkey, s_name, s_address, s_phone, s_acctbal, s_comment, n_nationkey, n_name, n_comment, r_regionkey, r_name, r_comment

FROM lineitem, orders, partsupp, part, customer, supplier, nation, region

WHERE p_partkey = ps_partkey

AND s_suppkey = ps_suppkey

AND n_nationkey = s_nationkey

AND r_regionkey = n_regionkey

AND c_custkey = o_custkey

AND ps_partkey = l_partkey

AND ps_suppkey = l_suppkey

AND o_orderkey = l_orderkey

# %% [markdown]
# ### Outer Joins
# ■ SchauspielerIn(Name, Adresse, Geschlecht, Geburtstag)
# <br><br>
# ■ ManagerIn(Name, Adresse, ManagerinID, Gehalt)
# <br><br>
# ■ Schauspieler*innen, die zugleich Manager*in sind

# %%
#SELECT Name, Adresse, Geburtstag, Gehalt 
#FROM SchauspielerIn 
#NATURAL INNER JOIN ManagerIn

__SQL__ = "SELECT Name, Adresse, Geburtstag, Gehalt FROM SchauspielerIn NATURAL INNER JOIN ManagerIn"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [44], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: no such column: Geburtstag

# %% [markdown]
# ■ SchauspielerIn und gegebenenfalls ihre ManagerIninfo

# %%
#…FROM SchauspielerIn NATURAL LEFT OUTER JOIN ManagerIn

# %% [markdown]
# □ Gehalt bleibt gegebenenfalls NULL
#
# ■ ManagerIn und gegebenenfalls ihre Schauspielerinfo

# %%
#…FROM SchauspielerIn NATURAL RIGHT OUTER JOIN ManagerIn

# %% [markdown]
# □ Geburtstag bleibt gegebenenfalls NULL
#
# ■ Alle Schauspieler*innen und Manager*innen

# %%
#…FROM SchauspielerIn NATURAL FULL OUTER JOIN ManagerIn

# %% [markdown]
# □ Geburtstag oder Gehalt bleiben gegebenenfalls leer
#
# □ Unterschied zu UNION: Nur eine Zeile pro Person
#
# ![](outerjoins.jpg)
#
# |Geburtstag|Name|Adresse|Gehalt|
# |---|---|---|---|
# |1.2.1960|Mark Hamill|LA|NULL|
# |27.5.1969|Carrie Fischer|New York|NULL|
# |11.12.1940|Alec Guinness|London|NULL|
# |22.3.1981|Ben Affleck|Boston|5Mio|
# |23.8.1973|Quentin Tarantino|Berlin|10Mio|
# |NULL|George Lukas |San Jose|100Mio|
# |NULL|Steven Spielberg|LA|500Mio|
#
# ->geschweifte Klammern fehlen in md Tabelle
#
# ### Kreuzprodukt
# ■ Alle Paare aus Tupeln der beteiligten Relationen

# %%
#SELECT * 
#FROM SchauspielerIn CROSS JOIN Film

__SQL__ = "SELECT * FROM SchauspielerIn CROSS JOIN Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Inside Out 2015 95 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Toy Story 1999 81 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Up 2009 96 TRUE Pixar 4567
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Ratatouille 2007 111 TRUE Pixar 4567
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Star Wars 1977 121 TRUE Pinewood 78910
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Star Trek 1979 132 TRUE Paramount  6789
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Into the Wild 2007 148 TRUE Paramount  6789
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Brokeback Mountain 2005 134 TRUE River Road 4712
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Lighthouse 2019 109 FALSE A24 1748
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Roma 2018 135 FALSE Participant 5123
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 La Heine 1995 98 FALSE NULL 2212
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Total Recall 1990 113 TRUE Fox 3310
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 La La Land 2016 128 TRUE Summit Entertainment 5123
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Moonlight 2016 124 TRUE A24 1748
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 House of Gucci 2021 158 TRUE MGM 5555
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Shipwrecked 1990 92 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Inside Out 2015 95 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Toy Story 1999 81 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Up 2009 96 TRUE Pixar 4567
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Ratatouille 2007 111 TRUE Pixar 4567
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Star Wars 1977 121 TRUE Pinewood 78910
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Star Trek 1979 132 TRUE Paramount  6789
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Into the Wild 2007 148 TRUE Paramount  6789
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Brokeback Mountain 2005 134 TRUE River Road 4712
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Lighthouse 2019 109 FALSE A24 1748
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Roma 2018 135 FALSE Participant 5123
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 La Heine 1995 98 FALSE NULL 2212
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Total Recall 1990 113 TRUE Fox 3310
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 La La Land 2016 128 TRUE Summit Entertainment 5123
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Moonlight 2016 124 TRUE A24 1748
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 House of Gucci 2021 158 TRUE MGM 5555
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Shipwrecked 1990 92 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Inside Out 2015 95 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Toy Story 1999 81 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Up 2009 96 TRUE Pixar 4567
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Ratatouille 2007 111 TRUE Pixar 4567
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Star Wars 1977 121 TRUE Pinewood 78910
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Star Trek 1979 132 TRUE Paramount  6789
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Into the Wild 2007 148 TRUE Paramount  6789
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Brokeback Mountain 2005 134 TRUE River Road 4712
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Lighthouse 2019 109 FALSE A24 1748
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Roma 2018 135 FALSE Participant 5123
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 La Heine 1995 98 FALSE NULL 2212
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Total Recall 1990 113 TRUE Fox 3310
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 La La Land 2016 128 TRUE Summit Entertainment 5123
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Moonlight 2016 124 TRUE A24 1748
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 House of Gucci 2021 158 TRUE MGM 5555
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Shipwrecked 1990 92 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Inside Out 2015 95 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Toy Story 1999 81 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Up 2009 96 TRUE Pixar 4567
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Ratatouille 2007 111 TRUE Pixar 4567
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Star Wars 1977 121 TRUE Pinewood 78910
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Star Trek 1979 132 TRUE Paramount  6789
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Into the Wild 2007 148 TRUE Paramount  6789
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Brokeback Mountain 2005 134 TRUE River Road 4712
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Lighthouse 2019 109 FALSE A24 1748
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Roma 2018 135 FALSE Participant 5123
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 La Heine 1995 98 FALSE NULL 2212
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Total Recall 1990 113 TRUE Fox 3310
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 La La Land 2016 128 TRUE Summit Entertainment 5123
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Moonlight 2016 124 TRUE A24 1748
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 House of Gucci 2021 158 TRUE MGM 5555
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Shipwrecked 1990 92 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Inside Out 2015 95 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Toy Story 1999 81 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Up 2009 96 TRUE Pixar 4567
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Ratatouille 2007 111 TRUE Pixar 4567
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Star Wars 1977 121 TRUE Pinewood 78910
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Star Trek 1979 132 TRUE Paramount  6789
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Into the Wild 2007 148 TRUE Paramount  6789
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Brokeback Mountain 2005 134 TRUE River Road 4712
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Lighthouse 2019 109 FALSE A24 1748
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Roma 2018 135 FALSE Participant 5123
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 La Heine 1995 98 FALSE NULL 2212
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Total Recall 1990 113 TRUE Fox 3310
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 La La Land 2016 128 TRUE Summit Entertainment 5123
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Moonlight 2016 124 TRUE A24 1748
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 House of Gucci 2021 158 TRUE MGM 5555
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Shipwrecked 1990 92 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Inside Out 2015 95 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Toy Story 1999 81 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Up 2009 96 TRUE Pixar 4567
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Ratatouille 2007 111 TRUE Pixar 4567
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Star Wars 1977 121 TRUE Pinewood 78910
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Star Trek 1979 132 TRUE Paramount  6789
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Into the Wild 2007 148 TRUE Paramount  6789
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Brokeback Mountain 2005 134 TRUE River Road 4712
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Lighthouse 2019 109 FALSE A24 1748
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Roma 2018 135 FALSE Participant 5123
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 La Heine 1995 98 FALSE NULL 2212
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Total Recall 1990 113 TRUE Fox 3310
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 La La Land 2016 128 TRUE Summit Entertainment 5123
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Moonlight 2016 124 TRUE A24 1748
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 House of Gucci 2021 158 TRUE MGM 5555
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Shipwrecked 1990 92 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Inside Out 2015 95 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Toy Story 1999 81 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Up 2009 96 TRUE Pixar 4567
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Ratatouille 2007 111 TRUE Pixar 4567
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Star Wars 1977 121 TRUE Pinewood 78910
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Star Trek 1979 132 TRUE Paramount  6789
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Into the Wild 2007 148 TRUE Paramount  6789
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Brokeback Mountain 2005 134 TRUE River Road 4712
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Lighthouse 2019 109 FALSE A24 1748
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Roma 2018 135 FALSE Participant 5123
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 La Heine 1995 98 FALSE NULL 2212
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Total Recall 1990 113 TRUE Fox 3310
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 La La Land 2016 128 TRUE Summit Entertainment 5123
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Moonlight 2016 124 TRUE A24 1748
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 House of Gucci 2021 158 TRUE MGM 5555
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Shipwrecked 1990 92 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Inside Out 2015 95 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Toy Story 1999 81 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Up 2009 96 TRUE Pixar 4567
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Ratatouille 2007 111 TRUE Pixar 4567
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Star Wars 1977 121 TRUE Pinewood 78910
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Star Trek 1979 132 TRUE Paramount  6789
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Into the Wild 2007 148 TRUE Paramount  6789
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Brokeback Mountain 2005 134 TRUE River Road 4712
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Lighthouse 2019 109 FALSE A24 1748
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Roma 2018 135 FALSE Participant 5123
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 La Heine 1995 98 FALSE NULL 2212
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Total Recall 1990 113 TRUE Fox 3310
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 La La Land 2016 128 TRUE Summit Entertainment 5123
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Moonlight 2016 124 TRUE A24 1748
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 House of Gucci 2021 158 TRUE MGM 5555
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Shipwrecked 1990 92 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Inside Out 2015 95 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Toy Story 1999 81 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Up 2009 96 TRUE Pixar 4567
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Ratatouille 2007 111 TRUE Pixar 4567
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Star Wars 1977 121 TRUE Pinewood 78910
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Star Trek 1979 132 TRUE Paramount  6789
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Into the Wild 2007 148 TRUE Paramount  6789
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Brokeback Mountain 2005 134 TRUE River Road 4712
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Lighthouse 2019 109 FALSE A24 1748
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Roma 2018 135 FALSE Participant 5123
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 La Heine 1995 98 FALSE NULL 2212
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Total Recall 1990 113 TRUE Fox 3310
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 La La Land 2016 128 TRUE Summit Entertainment 5123
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Moonlight 2016 124 TRUE A24 1748
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 House of Gucci 2021 158 TRUE MGM 5555
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Shipwrecked 1990 92 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Inside Out 2015 95 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Toy Story 1999 81 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Up 2009 96 TRUE Pixar 4567
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Ratatouille 2007 111 TRUE Pixar 4567
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Star Wars 1977 121 TRUE Pinewood 78910
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Star Trek 1979 132 TRUE Paramount  6789
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Into the Wild 2007 148 TRUE Paramount  6789
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Brokeback Mountain 2005 134 TRUE River Road 4712
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Lighthouse 2019 109 FALSE A24 1748
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Roma 2018 135 FALSE Participant 5123
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 La Heine 1995 98 FALSE NULL 2212
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Total Recall 1990 113 TRUE Fox 3310
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 La La Land 2016 128 TRUE Summit Entertainment 5123
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Moonlight 2016 124 TRUE A24 1748
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 House of Gucci 2021 158 TRUE MGM 5555
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Shipwrecked 1990 92 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Inside Out 2015 95 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Toy Story 1999 81 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Up 2009 96 TRUE Pixar 4567
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Ratatouille 2007 111 TRUE Pixar 4567
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Star Wars 1977 121 TRUE Pinewood 78910
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Star Trek 1979 132 TRUE Paramount  6789
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Into the Wild 2007 148 TRUE Paramount  6789
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Brokeback Mountain 2005 134 TRUE River Road 4712
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Lighthouse 2019 109 FALSE A24 1748
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Roma 2018 135 FALSE Participant 5123
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 La Heine 1995 98 FALSE NULL 2212
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Total Recall 1990 113 TRUE Fox 3310
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 La La Land 2016 128 TRUE Summit Entertainment 5123
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Moonlight 2016 124 TRUE A24 1748
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 House of Gucci 2021 158 TRUE MGM 5555
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Shipwrecked 1990 92 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Inside Out 2015 95 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Toy Story 1999 81 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Up 2009 96 TRUE Pixar 4567
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Ratatouille 2007 111 TRUE Pixar 4567
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Star Wars 1977 121 TRUE Pinewood 78910
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Star Trek 1979 132 TRUE Paramount  6789
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Into the Wild 2007 148 TRUE Paramount  6789
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Brokeback Mountain 2005 134 TRUE River Road 4712
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Lighthouse 2019 109 FALSE A24 1748
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Roma 2018 135 FALSE Participant 5123
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 La Heine 1995 98 FALSE NULL 2212
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Total Recall 1990 113 TRUE Fox 3310
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 La La Land 2016 128 TRUE Summit Entertainment 5123
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Moonlight 2016 124 TRUE A24 1748
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 House of Gucci 2021 158 TRUE MGM 5555
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Shipwrecked 1990 92 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Inside Out 2015 95 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Toy Story 1999 81 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Up 2009 96 TRUE Pixar 4567
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Ratatouille 2007 111 TRUE Pixar 4567
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Star Wars 1977 121 TRUE Pinewood 78910
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Star Trek 1979 132 TRUE Paramount  6789
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Into the Wild 2007 148 TRUE Paramount  6789
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Brokeback Mountain 2005 134 TRUE River Road 4712
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Lighthouse 2019 109 FALSE A24 1748
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Roma 2018 135 FALSE Participant 5123
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 La Heine 1995 98 FALSE NULL 2212
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Total Recall 1990 113 TRUE Fox 3310
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 La La Land 2016 128 TRUE Summit Entertainment 5123
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Moonlight 2016 124 TRUE A24 1748
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 House of Gucci 2021 158 TRUE MGM 5555
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Shipwrecked 1990 92 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Inside Out 2015 95 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Toy Story 1999 81 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Up 2009 96 TRUE Pixar 4567
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Ratatouille 2007 111 TRUE Pixar 4567
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Star Wars 1977 121 TRUE Pinewood 78910
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Star Trek 1979 132 TRUE Paramount  6789
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Into the Wild 2007 148 TRUE Paramount  6789
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Brokeback Mountain 2005 134 TRUE River Road 4712
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Lighthouse 2019 109 FALSE A24 1748
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Roma 2018 135 FALSE Participant 5123
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 La Heine 1995 98 FALSE NULL 2212
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Total Recall 1990 113 TRUE Fox 3310
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 La La Land 2016 128 TRUE Summit Entertainment 5123
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Moonlight 2016 124 TRUE A24 1748
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 House of Gucci 2021 158 TRUE MGM 5555
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Shipwrecked 1990 92 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Inside Out 2015 95 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Toy Story 1999 81 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Up 2009 96 TRUE Pixar 4567
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Ratatouille 2007 111 TRUE Pixar 4567
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Star Wars 1977 121 TRUE Pinewood 78910
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Star Trek 1979 132 TRUE Paramount  6789
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Into the Wild 2007 148 TRUE Paramount  6789
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Brokeback Mountain 2005 134 TRUE River Road 4712
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Lighthouse 2019 109 FALSE A24 1748
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Roma 2018 135 FALSE Participant 5123
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 La Heine 1995 98 FALSE NULL 2212
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Total Recall 1990 113 TRUE Fox 3310
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 La La Land 2016 128 TRUE Summit Entertainment 5123
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Moonlight 2016 124 TRUE A24 1748
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 House of Gucci 2021 158 TRUE MGM 5555
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Shipwrecked 1990 92 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Willem Dafoe 9601 Wilshire Blvd., 3rd Floor, Beverly Hills, CA 90210-5213 m 1995-07-22 Inside Out 2015 95 TRUE Disney 1234
# ...
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Brokeback Mountain 2005 134 TRUE River Road 4712
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Lighthouse 2019 109 FALSE A24 1748
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Roma 2018 135 FALSE Participant 5123
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 La Heine 1995 98 FALSE NULL 2212
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Total Recall 1990 113 TRUE Fox 3310
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 La La Land 2016 128 TRUE Summit Entertainment 5123
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Moonlight 2016 124 TRUE A24 1748
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 House of Gucci 2021 158 TRUE MGM 5555
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Shipwrecked 1990 92 TRUE Disney 1234
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Inside Out 2015 95 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Toy Story 1999 81 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Up 2009 96 TRUE Pixar 4567
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Ratatouille 2007 111 TRUE Pixar 4567
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Star Wars 1977 121 TRUE Pinewood 78910
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Star Trek 1979 132 TRUE Paramount  6789
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Into the Wild 2007 148 TRUE Paramount  6789
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Brokeback Mountain 2005 134 TRUE River Road 4712
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Lighthouse 2019 109 FALSE A24 1748
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Roma 2018 135 FALSE Participant 5123
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 La Heine 1995 98 FALSE NULL 2212
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Total Recall 1990 113 TRUE Fox 3310
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 La La Land 2016 128 TRUE Summit Entertainment 5123
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Moonlight 2016 124 TRUE A24 1748
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 House of Gucci 2021 158 TRUE MGM 5555
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Shipwrecked 1990 92 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Inside Out 2015 95 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Toy Story 1999 81 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Up 2009 96 TRUE Pixar 4567
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Ratatouille 2007 111 TRUE Pixar 4567
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Star Wars 1977 121 TRUE Pinewood 78910
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Star Trek 1979 132 TRUE Paramount  6789
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Into the Wild 2007 148 TRUE Paramount  6789
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Brokeback Mountain 2005 134 TRUE River Road 4712
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Lighthouse 2019 109 FALSE A24 1748
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Roma 2018 135 FALSE Participant 5123
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 La Heine 1995 98 FALSE NULL 2212
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Total Recall 1990 113 TRUE Fox 3310
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 La La Land 2016 128 TRUE Summit Entertainment 5123
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Moonlight 2016 124 TRUE A24 1748
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 House of Gucci 2021 158 TRUE MGM 5555
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Shipwrecked 1990 92 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Inside Out 2015 95 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Toy Story 1999 81 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Up 2009 96 TRUE Pixar 4567
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Ratatouille 2007 111 TRUE Pixar 4567
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Star Wars 1977 121 TRUE Pinewood 78910
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Star Trek 1979 132 TRUE Paramount  6789
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Into the Wild 2007 148 TRUE Paramount  6789
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Brokeback Mountain 2005 134 TRUE River Road 4712
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Lighthouse 2019 109 FALSE A24 1748
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Roma 2018 135 FALSE Participant 5123
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 La Heine 1995 98 FALSE NULL 2212
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Total Recall 1990 113 TRUE Fox 3310
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 La La Land 2016 128 TRUE Summit Entertainment 5123
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Moonlight 2016 124 TRUE A24 1748
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 House of Gucci 2021 158 TRUE MGM 5555
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Shipwrecked 1990 92 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Inside Out 2015 95 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Toy Story 1999 81 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Up 2009 96 TRUE Pixar 4567
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Ratatouille 2007 111 TRUE Pixar 4567
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Star Wars 1977 121 TRUE Pinewood 78910
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Star Trek 1979 132 TRUE Paramount  6789
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Into the Wild 2007 148 TRUE Paramount  6789
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Brokeback Mountain 2005 134 TRUE River Road 4712
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Lighthouse 2019 109 FALSE A24 1748
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Roma 2018 135 FALSE Participant 5123
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 La Heine 1995 98 FALSE NULL 2212
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Total Recall 1990 113 TRUE Fox 3310
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 La La Land 2016 128 TRUE Summit Entertainment 5123
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Moonlight 2016 124 TRUE A24 1748
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 House of Gucci 2021 158 TRUE MGM 5555
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Shipwrecked 1990 92 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Inside Out 2015 95 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Toy Story 1999 81 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Up 2009 96 TRUE Pixar 4567
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Ratatouille 2007 111 TRUE Pixar 4567
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Star Wars 1977 121 TRUE Pinewood 78910
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Star Trek 1979 132 TRUE Paramount  6789
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Into the Wild 2007 148 TRUE Paramount  6789
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Brokeback Mountain 2005 134 TRUE River Road 4712
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Lighthouse 2019 109 FALSE A24 1748
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Roma 2018 135 FALSE Participant 5123
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 La Heine 1995 98 FALSE NULL 2212
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Total Recall 1990 113 TRUE Fox 3310
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 La La Land 2016 128 TRUE Summit Entertainment 5123
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Moonlight 2016 124 TRUE A24 1748
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 House of Gucci 2021 158 TRUE MGM 5555
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Shipwrecked 1990 92 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Rescuers Down Under 1990 77 TRUE Disney 1234

# %%
#SELECT * 
#FROM SchauspielerIn, Film

__SQL__ = "SELECT * FROM SchauspielerIn, Film"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Inside Out 2015 95 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Toy Story 1999 81 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Up 2009 96 TRUE Pixar 4567
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Ratatouille 2007 111 TRUE Pixar 4567
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Star Wars 1977 121 TRUE Pinewood 78910
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Star Trek 1979 132 TRUE Paramount  6789
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Into the Wild 2007 148 TRUE Paramount  6789
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Brokeback Mountain 2005 134 TRUE River Road 4712
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Lighthouse 2019 109 FALSE A24 1748
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Roma 2018 135 FALSE Participant 5123
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 La Heine 1995 98 FALSE NULL 2212
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Total Recall 1990 113 TRUE Fox 3310
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 La La Land 2016 128 TRUE Summit Entertainment 5123
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Moonlight 2016 124 TRUE A24 1748
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 House of Gucci 2021 158 TRUE MGM 5555
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 Shipwrecked 1990 92 TRUE Disney 1234
# Sharon Stone 407 N Maple Dr Suite 100, Beverly Hills, CA 90210-3818 f 1958-03-10 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Inside Out 2015 95 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Toy Story 1999 81 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Up 2009 96 TRUE Pixar 4567
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Ratatouille 2007 111 TRUE Pixar 4567
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Star Wars 1977 121 TRUE Pinewood 78910
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Star Trek 1979 132 TRUE Paramount  6789
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Into the Wild 2007 148 TRUE Paramount  6789
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Brokeback Mountain 2005 134 TRUE River Road 4712
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Lighthouse 2019 109 FALSE A24 1748
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Roma 2018 135 FALSE Participant 5123
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 La Heine 1995 98 FALSE NULL 2212
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Total Recall 1990 113 TRUE Fox 3310
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 La La Land 2016 128 TRUE Summit Entertainment 5123
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Moonlight 2016 124 TRUE A24 1748
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 House of Gucci 2021 158 TRUE MGM 5555
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 Shipwrecked 1990 92 TRUE Disney 1234
# Robert Pattinson William Morris Endeavor Entertainment, 9601 Wilshire Blvd. 3rd Floor, Beverly Hills, CA 90210-5213 m 1986-05-13 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Inside Out 2015 95 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Toy Story 1999 81 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Up 2009 96 TRUE Pixar 4567
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Ratatouille 2007 111 TRUE Pixar 4567
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Star Wars 1977 121 TRUE Pinewood 78910
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Star Trek 1979 132 TRUE Paramount  6789
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Into the Wild 2007 148 TRUE Paramount  6789
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Brokeback Mountain 2005 134 TRUE River Road 4712
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Lighthouse 2019 109 FALSE A24 1748
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Roma 2018 135 FALSE Participant 5123
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 La Heine 1995 98 FALSE NULL 2212
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Total Recall 1990 113 TRUE Fox 3310
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 La La Land 2016 128 TRUE Summit Entertainment 5123
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Moonlight 2016 124 TRUE A24 1748
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 House of Gucci 2021 158 TRUE MGM 5555
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 Shipwrecked 1990 92 TRUE Disney 1234
# Scarlet Johansson 15821 Ventura Blvs., Suite 370, Encino CA 91436 USA f 1984-11-22 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Inside Out 2015 95 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Toy Story 1999 81 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Up 2009 96 TRUE Pixar 4567
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Ratatouille 2007 111 TRUE Pixar 4567
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Star Wars 1977 121 TRUE Pinewood 78910
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Star Trek 1979 132 TRUE Paramount  6789
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Into the Wild 2007 148 TRUE Paramount  6789
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Brokeback Mountain 2005 134 TRUE River Road 4712
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Lighthouse 2019 109 FALSE A24 1748
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Roma 2018 135 FALSE Participant 5123
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 La Heine 1995 98 FALSE NULL 2212
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Total Recall 1990 113 TRUE Fox 3310
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 La La Land 2016 128 TRUE Summit Entertainment 5123
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Moonlight 2016 124 TRUE A24 1748
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 House of Gucci 2021 158 TRUE MGM 5555
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 Shipwrecked 1990 92 TRUE Disney 1234
# Saorise Ronan MacFarlane Chard Associates Ltd., 24 Adelaide Street, Dun Laoghaire Co. Dublin f 1994-04-12 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Inside Out 2015 95 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Toy Story 1999 81 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Up 2009 96 TRUE Pixar 4567
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Ratatouille 2007 111 TRUE Pixar 4567
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Star Wars 1977 121 TRUE Pinewood 78910
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Star Trek 1979 132 TRUE Paramount  6789
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Into the Wild 2007 148 TRUE Paramount  6789
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Brokeback Mountain 2005 134 TRUE River Road 4712
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Lighthouse 2019 109 FALSE A24 1748
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Roma 2018 135 FALSE Participant 5123
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 La Heine 1995 98 FALSE NULL 2212
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Total Recall 1990 113 TRUE Fox 3310
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 La La Land 2016 128 TRUE Summit Entertainment 5123
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Moonlight 2016 124 TRUE A24 1748
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 House of Gucci 2021 158 TRUE MGM 5555
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 Shipwrecked 1990 92 TRUE Disney 1234
# Jake Gyllenhaal Wilshire Boulevard, 3rd Floor, Beverly Hills, 90210-5213, California m 1980-12-19 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Inside Out 2015 95 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Toy Story 1999 81 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Up 2009 96 TRUE Pixar 4567
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Ratatouille 2007 111 TRUE Pixar 4567
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Star Wars 1977 121 TRUE Pinewood 78910
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Star Trek 1979 132 TRUE Paramount  6789
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Into the Wild 2007 148 TRUE Paramount  6789
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Brokeback Mountain 2005 134 TRUE River Road 4712
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Lighthouse 2019 109 FALSE A24 1748
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Roma 2018 135 FALSE Participant 5123
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 La Heine 1995 98 FALSE NULL 2212
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Total Recall 1990 113 TRUE Fox 3310
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 La La Land 2016 128 TRUE Summit Entertainment 5123
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Moonlight 2016 124 TRUE A24 1748
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 House of Gucci 2021 158 TRUE MGM 5555
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 Shipwrecked 1990 92 TRUE Disney 1234
# Heath Ledger 421 Broome Street, Lower Manhatta, New York City m 1979-04-04 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Inside Out 2015 95 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Toy Story 1999 81 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Up 2009 96 TRUE Pixar 4567
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Ratatouille 2007 111 TRUE Pixar 4567
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Star Wars 1977 121 TRUE Pinewood 78910
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Star Trek 1979 132 TRUE Paramount  6789
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Into the Wild 2007 148 TRUE Paramount  6789
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Brokeback Mountain 2005 134 TRUE River Road 4712
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Lighthouse 2019 109 FALSE A24 1748
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Roma 2018 135 FALSE Participant 5123
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 La Heine 1995 98 FALSE NULL 2212
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Total Recall 1990 113 TRUE Fox 3310
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 La La Land 2016 128 TRUE Summit Entertainment 5123
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Moonlight 2016 124 TRUE A24 1748
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 House of Gucci 2021 158 TRUE MGM 5555
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 Shipwrecked 1990 92 TRUE Disney 1234
# Mark Hamill P.O. Box 287, Grand Blanc, MI 48480 m 1951-09-25 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Inside Out 2015 95 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Toy Story 1999 81 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Up 2009 96 TRUE Pixar 4567
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Ratatouille 2007 111 TRUE Pixar 4567
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Star Wars 1977 121 TRUE Pinewood 78910
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Star Trek 1979 132 TRUE Paramount  6789
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Into the Wild 2007 148 TRUE Paramount  6789
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Brokeback Mountain 2005 134 TRUE River Road 4712
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Lighthouse 2019 109 FALSE A24 1748
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Roma 2018 135 FALSE Participant 5123
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 La Heine 1995 98 FALSE NULL 2212
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Total Recall 1990 113 TRUE Fox 3310
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 La La Land 2016 128 TRUE Summit Entertainment 5123
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Moonlight 2016 124 TRUE A24 1748
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 House of Gucci 2021 158 TRUE MGM 5555
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 Shipwrecked 1990 92 TRUE Disney 1234
# Carrie Fisher 6514 Lankershim Blvd. North Hollywood, California f 1956-10-21 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Inside Out 2015 95 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Toy Story 1999 81 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Up 2009 96 TRUE Pixar 4567
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Ratatouille 2007 111 TRUE Pixar 4567
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Star Wars 1977 121 TRUE Pinewood 78910
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Star Trek 1979 132 TRUE Paramount  6789
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Into the Wild 2007 148 TRUE Paramount  6789
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Brokeback Mountain 2005 134 TRUE River Road 4712
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Lighthouse 2019 109 FALSE A24 1748
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Roma 2018 135 FALSE Participant 5123
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 La Heine 1995 98 FALSE NULL 2212
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Total Recall 1990 113 TRUE Fox 3310
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 La La Land 2016 128 TRUE Summit Entertainment 5123
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Moonlight 2016 124 TRUE A24 1748
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 House of Gucci 2021 158 TRUE MGM 5555
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 Shipwrecked 1990 92 TRUE Disney 1234
# Harrison Ford P.O. Box 49344 Los Angeles, CA 90049-0344 m 1942-07-13 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Inside Out 2015 95 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Toy Story 1999 81 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Up 2009 96 TRUE Pixar 4567
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Ratatouille 2007 111 TRUE Pixar 4567
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Star Wars 1977 121 TRUE Pinewood 78910
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Star Trek 1979 132 TRUE Paramount  6789
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Into the Wild 2007 148 TRUE Paramount  6789
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Brokeback Mountain 2005 134 TRUE River Road 4712
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Lighthouse 2019 109 FALSE A24 1748
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Roma 2018 135 FALSE Participant 5123
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 La Heine 1995 98 FALSE NULL 2212
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Total Recall 1990 113 TRUE Fox 3310
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 La La Land 2016 128 TRUE Summit Entertainment 5123
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Moonlight 2016 124 TRUE A24 1748
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 House of Gucci 2021 158 TRUE MGM 5555
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 Shipwrecked 1990 92 TRUE Disney 1234
# Emile Hirsch 9336 Civic Center Drive, Beverly Hills, CA 90210-3604 m 1985-03-13 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Inside Out 2015 95 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Toy Story 1999 81 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Up 2009 96 TRUE Pixar 4567
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Ratatouille 2007 111 TRUE Pixar 4567
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Star Wars 1977 121 TRUE Pinewood 78910
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Star Trek 1979 132 TRUE Paramount  6789
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Into the Wild 2007 148 TRUE Paramount  6789
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Brokeback Mountain 2005 134 TRUE River Road 4712
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Lighthouse 2019 109 FALSE A24 1748
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Roma 2018 135 FALSE Participant 5123
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 La Heine 1995 98 FALSE NULL 2212
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Total Recall 1990 113 TRUE Fox 3310
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 La La Land 2016 128 TRUE Summit Entertainment 5123
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Moonlight 2016 124 TRUE A24 1748
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 House of Gucci 2021 158 TRUE MGM 5555
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 Shipwrecked 1990 92 TRUE Disney 1234
# Vincent Cassel 42/44 rue de Paradis, 75010 Paris m 1966-11-23 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Inside Out 2015 95 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Toy Story 1999 81 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Up 2009 96 TRUE Pixar 4567
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Ratatouille 2007 111 TRUE Pixar 4567
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Star Wars 1977 121 TRUE Pinewood 78910
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Star Trek 1979 132 TRUE Paramount  6789
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Into the Wild 2007 148 TRUE Paramount  6789
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Brokeback Mountain 2005 134 TRUE River Road 4712
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Lighthouse 2019 109 FALSE A24 1748
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Roma 2018 135 FALSE Participant 5123
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 La Heine 1995 98 FALSE NULL 2212
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Total Recall 1990 113 TRUE Fox 3310
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 La La Land 2016 128 TRUE Summit Entertainment 5123
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Moonlight 2016 124 TRUE A24 1748
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 House of Gucci 2021 158 TRUE MGM 5555
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 Shipwrecked 1990 92 TRUE Disney 1234
# Meryl Streep 42 West, 600 3rd Avenue, 23rd Floor, New York f 1949-06-22 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Inside Out 2015 95 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Toy Story 1999 81 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Up 2009 96 TRUE Pixar 4567
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Ratatouille 2007 111 TRUE Pixar 4567
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Star Wars 1977 121 TRUE Pinewood 78910
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Star Trek 1979 132 TRUE Paramount  6789
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Into the Wild 2007 148 TRUE Paramount  6789
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Brokeback Mountain 2005 134 TRUE River Road 4712
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Lighthouse 2019 109 FALSE A24 1748
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Roma 2018 135 FALSE Participant 5123
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 La Heine 1995 98 FALSE NULL 2212
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Total Recall 1990 113 TRUE Fox 3310
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 La La Land 2016 128 TRUE Summit Entertainment 5123
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Moonlight 2016 124 TRUE A24 1748
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 House of Gucci 2021 158 TRUE MGM 5555
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 Shipwrecked 1990 92 TRUE Disney 1234
# Cameron Diaz 2000 Avenue Of The Stars, 3rd Floor, North Tower, Century City, CA 90067 f 1972-08-30 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Inside Out 2015 95 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Toy Story 1999 81 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Up 2009 96 TRUE Pixar 4567
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Ratatouille 2007 111 TRUE Pixar 4567
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Star Wars 1977 121 TRUE Pinewood 78910
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Star Trek 1979 132 TRUE Paramount  6789
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Into the Wild 2007 148 TRUE Paramount  6789
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Brokeback Mountain 2005 134 TRUE River Road 4712
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Lighthouse 2019 109 FALSE A24 1748
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Roma 2018 135 FALSE Participant 5123
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 La Heine 1995 98 FALSE NULL 2212
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Total Recall 1990 113 TRUE Fox 3310
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 La La Land 2016 128 TRUE Summit Entertainment 5123
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Moonlight 2016 124 TRUE A24 1748
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 House of Gucci 2021 158 TRUE MGM 5555
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 Shipwrecked 1990 92 TRUE Disney 1234
# Emma Stone Wilshire Blvd., Suite 930, Beverly Hills, CA 90212 f 1988-11-06 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Inside Out 2015 95 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Toy Story 1999 81 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Up 2009 96 TRUE Pixar 4567
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Ratatouille 2007 111 TRUE Pixar 4567
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Star Wars 1977 121 TRUE Pinewood 78910
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Star Trek 1979 132 TRUE Paramount  6789
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Into the Wild 2007 148 TRUE Paramount  6789
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Brokeback Mountain 2005 134 TRUE River Road 4712
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Lighthouse 2019 109 FALSE A24 1748
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Roma 2018 135 FALSE Participant 5123
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 La Heine 1995 98 FALSE NULL 2212
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Total Recall 1990 113 TRUE Fox 3310
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 La La Land 2016 128 TRUE Summit Entertainment 5123
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Moonlight 2016 124 TRUE A24 1748
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 House of Gucci 2021 158 TRUE MGM 5555
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 Shipwrecked 1990 92 TRUE Disney 1234
# Phyllis Smith 8383 Wilshire Blvd., Suite 100, Beverly Hills, CA 90211 f 1951-07-10 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Willem Dafoe 9601 Wilshire Blvd., 3rd Floor, Beverly Hills, CA 90210-5213 m 1995-07-22 Inside Out 2015 95 TRUE Disney 1234
# ...
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Brokeback Mountain 2005 134 TRUE River Road 4712
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Lighthouse 2019 109 FALSE A24 1748
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Roma 2018 135 FALSE Participant 5123
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 La Heine 1995 98 FALSE NULL 2212
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Total Recall 1990 113 TRUE Fox 3310
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 La La Land 2016 128 TRUE Summit Entertainment 5123
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Moonlight 2016 124 TRUE A24 1748
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 House of Gucci 2021 158 TRUE MGM 5555
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 Shipwrecked 1990 92 TRUE Disney 1234
# Jared Leto 6311 Romaine Street, Suite 7327, Los Angeles, CA 90038-2617 m 1971-12-26 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Inside Out 2015 95 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Toy Story 1999 81 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Up 2009 96 TRUE Pixar 4567
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Ratatouille 2007 111 TRUE Pixar 4567
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Star Wars 1977 121 TRUE Pinewood 78910
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Star Trek 1979 132 TRUE Paramount  6789
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Into the Wild 2007 148 TRUE Paramount  6789
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Brokeback Mountain 2005 134 TRUE River Road 4712
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Lighthouse 2019 109 FALSE A24 1748
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Roma 2018 135 FALSE Participant 5123
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 La Heine 1995 98 FALSE NULL 2212
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Total Recall 1990 113 TRUE Fox 3310
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 La La Land 2016 128 TRUE Summit Entertainment 5123
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Moonlight 2016 124 TRUE A24 1748
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 House of Gucci 2021 158 TRUE MGM 5555
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 Shipwrecked 1990 92 TRUE Disney 1234
# Adam Driver 15260 Ventura Blvd. Suite 900, Sherman Oaks, CA 91403 m 1983-11-19 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Inside Out 2015 95 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Toy Story 1999 81 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Up 2009 96 TRUE Pixar 4567
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Ratatouille 2007 111 TRUE Pixar 4567
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Star Wars 1977 121 TRUE Pinewood 78910
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Star Trek 1979 132 TRUE Paramount  6789
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Into the Wild 2007 148 TRUE Paramount  6789
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Brokeback Mountain 2005 134 TRUE River Road 4712
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Lighthouse 2019 109 FALSE A24 1748
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Roma 2018 135 FALSE Participant 5123
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 La Heine 1995 98 FALSE NULL 2212
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Total Recall 1990 113 TRUE Fox 3310
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 La La Land 2016 128 TRUE Summit Entertainment 5123
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Moonlight 2016 124 TRUE A24 1748
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 House of Gucci 2021 158 TRUE MGM 5555
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 Shipwrecked 1990 92 TRUE Disney 1234
# Lady Gaga 401 Broadway Suite 206, New York, NY 10013 f 1986-03-20 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Inside Out 2015 95 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Toy Story 1999 81 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Up 2009 96 TRUE Pixar 4567
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Ratatouille 2007 111 TRUE Pixar 4567
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Star Wars 1977 121 TRUE Pinewood 78910
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Star Trek 1979 132 TRUE Paramount  6789
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Into the Wild 2007 148 TRUE Paramount  6789
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Brokeback Mountain 2005 134 TRUE River Road 4712
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Lighthouse 2019 109 FALSE A24 1748
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Roma 2018 135 FALSE Participant 5123
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 La Heine 1995 98 FALSE NULL 2212
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Total Recall 1990 113 TRUE Fox 3310
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 La La Land 2016 128 TRUE Summit Entertainment 5123
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Moonlight 2016 124 TRUE A24 1748
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 House of Gucci 2021 158 TRUE MGM 5555
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 Shipwrecked 1990 92 TRUE Disney 1234
# Daniel Craig 40 Whitfield Street, London, W1T 2RH m 1968-03-02 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Inside Out 2015 95 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Toy Story 1999 81 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Up 2009 96 TRUE Pixar 4567
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Ratatouille 2007 111 TRUE Pixar 4567
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Star Wars 1977 121 TRUE Pinewood 78910
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Star Trek 1979 132 TRUE Paramount  6789
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Into the Wild 2007 148 TRUE Paramount  6789
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Brokeback Mountain 2005 134 TRUE River Road 4712
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Lighthouse 2019 109 FALSE A24 1748
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Roma 2018 135 FALSE Participant 5123
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 La Heine 1995 98 FALSE NULL 2212
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Total Recall 1990 113 TRUE Fox 3310
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 La La Land 2016 128 TRUE Summit Entertainment 5123
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Moonlight 2016 124 TRUE A24 1748
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 House of Gucci 2021 158 TRUE MGM 5555
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 Shipwrecked 1990 92 TRUE Disney 1234
# Léa Seydoux 42/44 rue de Paradis, 75010 Paris f 1985-07-01 The Rescuers Down Under 1990 77 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Inside Out 2015 95 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Toy Story 1999 81 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Up 2009 96 TRUE Pixar 4567
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Ratatouille 2007 111 TRUE Pixar 4567
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Star Wars 1977 121 TRUE Pinewood 78910
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Star Trek 1979 132 TRUE Paramount  6789
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Lady Bird 2017 95 TRUE Scott Rudin Productions 3456
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Into the Wild 2007 148 TRUE Paramount  6789
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Brokeback Mountain 2005 134 TRUE River Road 4712
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Lighthouse 2019 109 FALSE A24 1748
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Roma 2018 135 FALSE Participant 5123
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 La Heine 1995 98 FALSE NULL 2212
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Total Recall 1990 113 TRUE Fox 3310
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Mamma Mia! 2008 108 TRUE Littlestar Productions 8871
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Dark Knight 2008 152 TRUE Warner Bros. 6035
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Pulp Fiction 1994 154 TRUE A Band Apart 7654
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Great Gatsby 2013 142 TRUE Village Roadshows  8634
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Spider-Man 2002 121 TRUE Marvel Enterprises 6362
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 La La Land 2016 128 TRUE Summit Entertainment 5123
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Moonlight 2016 124 TRUE A24 1748
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 House of Gucci 2021 158 TRUE MGM 5555
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 James Bond 007: Spectre 2015 148 TRUE MGM 5555
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 Shipwrecked 1990 92 TRUE Disney 1234
# Christoph Waltz Sophienstrasse 21, 10178 Berlin m 1956-10-04 The Rescuers Down Under 1990 77 TRUE Disney 1234

# %% [markdown]
# ■ Selten verwendet
# <br>
# ■ Grundbaustein für Joins
#
# ### Mengenoperationen in SQL
#  Vereinigung: UNION
# <br><br>
# ■ Schnittmenge: INTERSECT
# <br><br>
# ■ Differenz: EXCEPT / MINUS
# <br><br>
# ■ Mengenoperationen nur zwischen geklammerten Anfrageergebnissen
# <br><br>
# ■ Mengenoperationen haben implizit eine Mengensemantik
# <br>
# □ Wandeln Input-Relationen in Mengen um
# <br>
# □ Wandeln Output in Menge um
# <br><br>
# ■ Input-Relationen müssen gleiche Schemata haben
# <br>
# □ Gleiche Attributnamen
# <br>
# □ Gleiche Datentypen
# <br>
# ■ SchauspielerIn(Name, Adresse, Geschlecht, Geburtstag)
# <br><br>
# ■ ManagerIn(Name, Adresse, ManagerinID, Gehalt)
#
# #### Schnittmenge: INTERSECT
# ■ Entspricht dem logischen „und“

# %%
#(SELECT Name, Adresse FROM SchauspielerIn) INTERSECT (SELECT Name, Adresse FROM ManagerIn);

__SQL__ = "(SELECT Name, Adresse FROM SchauspielerIn) INTERSECT (SELECT Name, Adresse FROM ManagerIn)"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [49], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "(": syntax error

# %%
#%sql (SELECT Name, Adresse FROM SchauspielerIn WHERE Geschlecht = "f") INTERSECT (SELECT Name, Adresse FROM ManagerIn WHERE Gehalt > 1000000)

__SQL__ = "(SELECT Name, Adresse FROM SchauspielerIn WHERE Geschlecht = "f") INTERSECT (SELECT Name, Adresse FROM ManagerIn WHERE Gehalt > 1000000)"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [51], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "(": syntax error

# %% [markdown]
# ■ Multimengen-Semantik: INTERSECT ALL
#
# #### Vereinigung: UNION
# ■ Entspricht dem logischen „oder“

# %%
#(SELECT Name, Adresse FROM SchauspielerIn) UNION (SELECT Name, Adresse FROM ManagerIn);

__SQL__ = "(SELECT Name, Adresse FROM SchauspielerIn) UNION (SELECT Name, Adresse FROM ManagerIn)"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [52], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "(": syntax error

# %% [markdown]
# ■ Multimenge: UNION ALL
# <br>
# □ Beliebt, da schnell
# <br>
# □ Verwenden falls
# <br>
# – Semantik egal
# <br>
# – Multimengensemantik erwünscht
# <br>
# – Mengeneigenschaft von Input und Output bereits bekannt
#
# #### Differenz: EXCEPT
#
# ■ Auch MINUS

# %%
#%sql (SELECT Titel, Jahr FROM Film) EXCEPT (SELECT FilmTitel AS Titel, FilmJahr AS Jahr FROM spielt_in) 

__SQL__ = "(SELECT Titel, Jahr FROM Film) EXCEPT (SELECT FilmTitel AS Titel, FilmJahr AS Jahr FROM spielt_in)"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [53], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "(": syntax error

# %% [markdown]
# ■ Multimenge: EXCEPT ALL
#
# #### Klammerung

# %%
# %sql SELECT * FROM ((SELECT A FROM R)INTERSECT(SELECT * FROM (SELECT A FROM S) UNION (SELECT A FROM T)))

# %% [markdown]
# ### Zusammenfassung der Semantik
#
#
# |R1|R2|UNION ALL|UNION|EXCEPT ALL|EXCEPT|INTERSECT ALL|INTERSECT|
# |---|---|---|---|---|---|---|---|
# |1|1|1|1|1|2|1|1|
# |1|1|1|2|2|5|1|3|
# |1|3|1|3|2|&#xfeff;|3|4|
# |2|3|1|4|2|&#xfeff;|4|
# |2|3|1|5|4|
# |2|3|2|&#xfeff;|5|
# |3|4|2|
# |4|&#xfeff;|2|
# |4|&#xfeff;|3|
# |5|&#xfeff;|3|
# |&#xfeff;|&#xfeff;|3|
# |&#xfeff;|&#xfeff;|3|
# |&#xfeff;|&#xfeff;|3|
# |&#xfeff;|&#xfeff;|4|
# |&#xfeff;|&#xfeff;|4|
# |&#xfeff;|&#xfeff;|4|
# |&#xfeff;|&#xfeff;|5|

# %% [markdown]
# ## Geschachtelte Anfragen
# ### Motivation
# ■ Eine Anfrage kann Teil einer anderen Anfrage sein.
# <br>
# □ Theoretisch beliebig tiefe Schachtelung
# <br><br>
# ■ Drei Varianten
# <br>
# 1. Subanfrage erzeugt einen einzigen Wert, der in der WHERE-Klausel mit einem anderen Wert verglichen
# werden kann.
# <br>
# 2. Subanfrage erzeugt eine Relation, die auf verschiedene Weise in WHERE-Klausel verwendet werden kann.
# <br>
# 3. Subanfrage erzeugt eine Relation, die in der FROM Klausel verwendet werden kann.
# <br>
# – Wie jede normale Relation
#
# ### Skalare Subanfragen
#
# ■ Allgemeine Anfragen produzieren Relationen.
# <br>
# □ Mit mehreren Attributen
# <br>
# – Zugriff auf ein bestimmtes Attribut ist möglich
# <br>
# □ i.A. mit mehreren Tupeln
# <br>
# □ Manchmal (garantiert) nur maximal ein Tupel und Projektion auf nur ein Attribut
# <br>
# – „Skalare Anfrage“
# <br>
# – Verwendung wie eine Konstante möglich
# <br>
# – Falls keine Zeile: null
# <br>
# ![title](skalare_subanfragen.jpg)
# <br>
# ■ ManagerIn(Name, Adresse, ManagerinID, Gehalt)
# <br>
# ■ Film(Titel, Jahr, Länge, inFarbe, StudioName, ProduzentinID)
# <br>
# ■ Gesucht: Produzent von Star Wars

# %%
#SELECT Name 
#FROM Film, ManagerIn 
#WHERE Titel = ‘Star Wars‘ 
#AND Jahr = ‘1977‘ 
#AND ProduzentinID = ManagerinID;

__SQL__ = "SELECT Name FROM Film, ManagerIn WHERE Titel = 'Star Wars' AND Jahr = 1977 AND ProduzentinID = ManagerinID"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Paul Golding

# %% [markdown]
# ■ Oder aber

# %%
#SELECT Name FROM ManagerIn 
#WHERE ManagerinID = ( SELECT ProduzentinID FROM Film WHERE Titel = "Star Wars" AND Jahr = 1977 );

__SQL__ = "SELECT Name FROM ManagerIn WHERE ManagerinID = ( SELECT ProduzentinID FROM Film WHERE Titel = 'Star Wars' AND Jahr = 1977 );"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Paul Golding

# %% [markdown]
# ■ DBMS erwartet maximal ein Tupel als Ergebnis der Teilanfrage
# <br>
# □ Falls kein Tupel: null
# <br>
# □ Falls mehr als ein Tupel: Laufzeitfehler
#
# #### Skalare Subanfragen – Beispiel
# ■ Abteilungen, deren durchschnittliche Bonuszahlungen höher sind als deren durchschnittliches Gehalt.

# %%
# %sql
SELECT a.Name, a.Standort FROM Abteilung a WHERE (SELECT AVG(bonus) FROM personal p WHERE a.AbtID = p.AbtID)>(SELECT AVG(gehalt)FROM personal pWHERE a.AbtID = p.AbtID)

# %% [markdown]
# ■ Alle Potsdamer Abteilungen mit ihrem Maximalgehalt.

# %%
# %sql
SELECT a.AbtID, a.Name,
           (SELECT MAX(Gehalt)
                FROM Personal p
            WHERE a.AbtID = p.AbtID) AS maxGehalt
FROM Abteilung a
WHERE a.Ort = ‘Potsdam‘

# %% [markdown]
# ■ Anmerkung: Auch Abteilungen ohne Mitarbeiter erscheinen im Ergebnis.
# <br><br>
# ■ Nicht so in der folgenden Anfrage:

# %%
# %sql
SELECT a.AbtID, a.Name, MAX(p.Gehalt) AS maxGehalt
FROM Abteilung a, Personal p
WHERE a.Ort = ‘Potsdam‘
AND a.AbtID = p.AbtID
GROUP BY a.AbtID, a.Name

# %% [markdown]
# ### Bedingungen mit Relationen
# ■ Bestimmte SQL Operatoren auf Relationen erzeugen Boole‘sche Werte
# <br>
# □ EXISTS R
# <br>
# – TRUE, falls R nicht leer
# <br>
# □ x IN R
# <br>
# – TRUE falls x gleich einem Wert in R ist (R hat nur ein Attribut)
# <br>
# – Verallgemeinerung auf Tupel später
# <br>
# – x NOT IN R: TRUE falls x keinem Wert in R gleicht
# <br>
# □ x > ALL R
# <br>
# – TRUE falls x größer als jeder Wert in R ist (R hat nur ein Attribut)
# <br>
# – Alternativ: <, >, <=, >=, <>, =
# <br>
# – x <> ALL R: Entspricht x NOT IN R bzw. auch NOT(x in R)
# <br>
# □ x > ANY R
# <br>
# – TRUE falls x größer als mindestens ein Wert in R ist (R hat nur ein Attribut)
# <br>
# – Alternativ: <, >, <=, >=, <>, =
# <br>
# – x = ANY R: Entspricht x IN R
# <br>
# – Alternativer Befehl: SOME
# <br>
# □ Negation mit NOT(…) ist immer möglich.
# ### EXISTS Beispiele
# ■ ISBNs aller ausgeliehenen Bücher

# %%
# %sql
SELECT ISBN
FROM BuchExemplar
WHERE EXISTS
     (SELECT *
      FROM Ausleihe
      WHERE Ausleihe.Inventarnr = BuchExemplar.Inventarnr)

# %% [markdown]
# ■ Lehrstuhlbezeichnungen der Professor*innen, die alle von ihnen gelesenen Vorlesungen auch schon einmal
# geprüft haben.
# <br><br>
# ■ bzw. Lehrstuhlbezeichnungen von Professor*innen, so dass keine von diesem gelesene Vorlesung existiert, die von
# ihm nicht geprüft wurde.

# %%
# %sql
SELECT Lehrstuhlbezeichnung
FROM Prof
WHERE NOT EXISTS
      (SELECT *
       FROM Liest
       WHERE Liest.PANr = Prof.PANr
       AND NOT EXISTS (SELECT *
                   FROM Prüft
                   WHERE Prüft.PANr = Prof.PANr
                   AND Prüft.VL_NR = Liest.VL_NR)
)

# %% [markdown]
# ### IN Beispiele
# ■ Eine Auswahl an Büchern

# %%
# %sql
SELECT Titel
FROM Bücher
WHERE ISBN IN (‘3898644006‘, ‘1608452204‘, ‘0130319953‘)

# %% [markdown]
# ■ Matrikel der Studenten, die zumindest einen Prüfer gemeinsam mit dem Studenten der Matrikel ‚123456‘ haben

# %%
# %sql
SELECT DISTINCT Matrikel
FROM Prüft
WHERE Prüfer IN ( SELECT Prüfer
                  FROM Prüft
                  WHERE Matrikel = ‘123456‘)```

# %%
# %sql
SELECT DISTINCT P1.Matrikel
FROM Prüft P1, Prüft P2
WHERE P2.Matrikel = `123456`
AND P1.Prüfer = P2.Prüfer

# %% [markdown]
# ■ Nachnamen aller Professor*innen, die schon einmal eine 1,0 vergeben haben.

# %%
# %sql
SELECT Nachname
FROM Prof
WHERE 1.0 IN ( SELECT Note
FROM Prüft
WHERE Prüfer = Prof.ID )

# %% [markdown]
# ■ Achtung: Korrelierte Subanfrage
#
# ### ALL und ANY Beispiele
#
# ■ Die schlechteste Note des Studenten mit Matrikel 123456

# %%
# %sql
SELECT Note
FROM Prüft
WHERE Matrikel = ‘123456‘
AND Note >= ALL (SELECT Note
                 FROM Prüft
                 WHERE Matrikel = ‘123456‘)

# %% [markdown]
# ■ Alle Studenten, die mindestens eine Prüfung absolvierten

# %%
# %sql 
SELECT Name, Matrikel
FROM Student
WHERE Matrikel = ANY (SELECT Matrikel
                      FROM Prüft)

# %% [markdown]
# ### Bedingungen mit Tupeln
# ■ Verallgemeinerung von IN, ALL und ANY auf Tupel
# <br>
# □ t IN R
# <br>
# – TRUE falls t ein Tupel in R ist (mehr als ein Attribut möglich)
# <br>
# – Setzt gleiche Schemata voraus
# <br>
# – Setzt gleiche Reihenfolge der Attribute voraus
# <br>
# □ t > ALL R
# <br>
# – TRUE falls t größer als jedes Tupel in R ist
# <br>
# – Vergleiche in Standardreihenfolge der Attribute
# <br>
# □ t <> ANY R
# <br>
# – TRUE falls R mindestens ein Tupel hat, das ungleich t ist
# <br>
# <br>
# ■ Namen von Produzenten von Filmen mit Harrison Ford

# %%
#SELECT Name 
#FROM ManagerIn 
#WHERE ManagerinID IN( SELECT ProduzentinID FROM Film WHERE (Titel, Jahr) 
#IN( SELECT FilmTitel AS Titel, FilmJahr AS Jahr FROM spielt_in WHERE Name = "Harrison Ford"));

__SQL__ = "SELECT Name FROM ManagerIn WHERE ManagerinID IN( SELECT ProduzentinID FROM Film WHERE (Titel, Jahr) IN( SELECT FilmTitel AS Titel, FilmJahr AS Jahr FROM spielt_in WHERE Name = 'Harrison Ford'))"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Paul Golding

# %% [markdown]
# ■ Analyse am besten von innen nach außen
# <br><br>
# ■ Alternative Formulierung

# %%
#SELECT Name 
#FROM ManagerIn, Film, spielt_in 
#WHERE ManagerinID = ProduzentinID 
#AND Titel = FilmTitel 
#AND Jahr = FilmJahr 
#AND SchauspielerIn.Name = "Harrison Ford";

__SQL__ = "SELECT Name FROM ManagerIn, Film, spielt_in WHERE ManagerinID = ProduzentinID AND Titel = FilmTitel AND Jahr = FilmJahr AND SchauspielerIn.Name = 'Harrison Ford'"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [61], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: ambiguous column name: Name

# %% [markdown]
# ### Subanfragen in FROM-Klausel
# ■ Bisher: Nur Subanfragen in WHERE-Klausel
# <br>
# □ Anstelle einfacher Relation steht eine geklammerte Subanfrage
# <br>
# □ Es muss ein Alias vergeben werden.
# <br>

# %%
#SELECT M.Name 
#FROM ManagerIn M, (SELECT ProduzentinID AS ID FROM Film, spielt_in WHERE Titel = FilmTitel AND Jahr = FilmJahr AND Name = "Harrison Ford") ProduzentIn 
#WHERE M.ManagerinID = ProduzentIn.ID;

__SQL__ = "SELECT M.Name FROM ManagerIn M, (SELECT ProduzentinID AS ID FROM Film, spielt_in WHERE Titel = FilmTitel AND Jahr = FilmJahr AND Name = 'Harrison Ford') ProduzentIn WHERE M.ManagerinID = ProduzentIn.ID"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Paul Golding

# %% [markdown]
# ### Korrelierte Subanfragen
# ■ Unkorreliert: Subanfragen einmalig ausführen und das Ergebnis weiterverwenden
# <br><br>
# ■ Korrelierte Subanfragen werden mehrfach ausgeführt, einmal pro Bindung der korrelierten Variable der äußeren
# Anfrage
# <br><br>
# ■ Alle mehrfachen Filme mit Ausnahme der jeweils jüngsten Ausgabe

# %%
#%sql SELECT Titel, Jahr 
#FROM Film Alt 
#WHERE Jahr < ANY ( SELECT Jahr FROM Film WHERE Titel = Alt.Titel);

__SQL__ = "SELECT Titel, Jahr FROM Film Alt WHERE Jahr < ANY ( SELECT Jahr FROM Film WHERE Titel = Alt.Titel)"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [65], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "SELECT": syntax error

# %% [markdown]
# □ Ausführung der Subanfrage für jedes Tupel in Filme
#
# Scope: Attributnamen gehören zunächst zur Tupelvariablen der aktuellen Anfrage. Sonst: Suche von innen nach außen.
#
# Unkorreliert:
# <br>
# Name und Gehalt aller Mitarbeiter in Potsdam

# %%
# %sql
SELECT Name, Gehalt
FROM Personal p
WHERE AbtID IN
    (SELECT AbtID
    FROM Abteilung
    WHERE Ort =
‘Potsdam‘)

# %% [markdown]
# Korreliert:
# <br>
# Name und Gehalt aller Mitarbeiter, deren Gehalt höher als 10% des Abteilungsbudgets ist.

# %%
# %sql
SELECT Name, Gehalt
FROM Personal p
WHERE Gehalt >
    (SELECT 0.1*Budget
    FROM Abteilung a
    WHERE a.AbtID =
p.AbtID)

# %% [markdown]
# ## Operationen auf einer Relation
# ### Duplikateliminierung
#  Relationale DBMS verwenden i.d.R. Multimengensemantik, nicht Mengensemantik.
#  <br>
# □ Duplikate entstehen durch
#  <br>
# – Einfügen von Duplikaten in Basisrelation
#  <br>
# – Veränderung von Tupeln in Basisrelation
#  <br>
# – Projektion in Anfragen
#  <br>
# – Durch Subanfragen (UNION ALL)
#  <br>
# – Vermehrung von Duplikaten durch Kreuzprodukt
#  <br> <br>
# ■ Duplikateliminierung
#  <br>
# □ SELECT DISTINCT Attributnamen
#  <br>
# □ Kosten sind hoch: Sortierung oder hashing
#  <br>
# ■ Alle Filme, in denen mindestens ein Schauspieler mitspielt

# %%
#SELECT DISTINCT FilmTitel, FilmJahr 
#FROM spielt_in

__SQL__ = "SELECT DISTINCT FilmTitel, FilmJahr FROM spielt_in"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Star Wars 1977
# Into the Wild 2007
# Brokeback Mountain 2005
# The Dark Knight 2008
# The Lighthouse 2019
# The Great Gatsby 2013
# Lady Bird 2017
# La Heine 1995
# Mamma Mia! 2008
# Inside Out 2015
# Total Recall 1990
# Pulp Fiction 1994
# Up 2009
# Spider-Man 2002
# La La Land 2016
# Moonlight 2016
# Star Trek 1979
# Ducktales the Movie: Treasure of the Lost Lamp 1990
# House of Gucci 2021
# James Bond 007: Spectre 2015

# %% [markdown]
# ![title](duplikateliminierung.jpg)
# #### Wdh.: Duplikateliminierung bei Mengenoperationen
# ■ Mengenoperationen in SQL entfernen Duplikate
# <br>
# □ UNION, INTERSECT, EXCEPT
# <br>
# □ wandeln Multimengen in Mengen um und verwenden Mengensemantik
# <br>
# □ Solche Duplikateliminierung verhindern durch ALL
# <br>

# %%
#(SELECT Titel, Jahr, FROM Film) UNION ALL (SELECT FilmTitel AS Titel, FilmJahr AS Jahr FROM spielt_in);

__SQL__ = "(SELECT Titel, Jahr, FROM Film) UNION ALL (SELECT FilmTitel AS Titel, FilmJahr AS Jahr FROM spielt_in)"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [69], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: near "(": syntax error

# %% [markdown]
# – Film mit drei Schauspielern erscheint also 4 Mal im Ergebnis
# <br>
# □ R INTERSECT ALL S
# <br>
# □ R EXCEPT ALL S
#
# ### Aggregation
# ■ Standardaggregationsoperatoren
# <br>
# □ SUM, AVG, MIN, MAX, COUNT
# <br>
# □ Angewendet auf einzelne Attribute in der SELECT-Klausel
# <br><br>
# ■ Typische weitere Aggregationsoperatoren
# <br>
# □ VAR, STDDEV
# <br><br>
# ■ COUNT(*) zählt Anzahl der Tupel
# <br>
# □ in der Relation, die durch die FROM und WHERE Klauseln definiert wird.
# <br><br>
# ■ Kombination mit DISTINCT
# <br>
# □ COUNT(DISTINCT Jahr)
# <br>
# □ SUM(DISTINCT Gehalt)
#
# #### Aggregation – Beispiele

# %%
#SELECT AVG(Gehalt) 
#FROM ManagerIn;

__SQL__ = "SELECT AVG(Gehalt) FROM ManagerIn"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# 251938.93333333332

# %%
#SELECT COUNT(*) 
#FROM spielt_in;

__SQL__ = "SELECT COUNT(*) FROM spielt_in;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# 34

# %%
#SELECT COUNT(Name) 
#FROM spielt_in;

__SQL__ = "SELECT COUNT(Name) FROM spielt_in;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# 34

# %%
#SELECT COUNT(DISTINCT Name) 
#FROM spielt_in 
#WHERE FilmJahr = 1990;

__SQL__ = "SELECT COUNT(DISTINCT Name) FROM spielt_in WHERE FilmJahr = 1990;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# 3

# %% [markdown]
# ### Gruppierung, Aggregation und NULL
# ■ NULL wird bei Aggregation ignoriert.
# <br>
# □ Trägt also nicht zu SUM, AVG oder COUNT bei.
# <br>
# □ Ist nicht MIN oder MAX
# <br>
# □ Anzahl Tupel: SELECT COUNT(*) FROM spielt_in;
# <br>
# □ Anzahl nicht-NULL Werte: SELECT COUNT(Länge) FROM Film;
# <br><br>
# ■ NULL ist ein eigener Gruppierungswert
# <br>
# □ Es gibt also z.B. die NULL-Gruppe
# <br>
# □ SELECT A, COUNT(B) FROM R GROUP BY A;
# <br>
# – Ergebnis: (NULL, 0)
# <br>
# □ SELECT A, SUM(B) FROM R GROUP BY A;
# <br>
# – Ergebnis: (NULL, NULL)
# <br>
#
# |A|B|
# |---|---|
# |NULL|NULL|
#
# ### Gruppierung
# ■ Gruppierung mittels GROUP BY nach der WHERE-Klausel

# %%
#SELECT StudioName, SUM(Laenge) 
#FROM Film GROUP BY StudioName

__SQL__ = "SELECT StudioName, SUM(Laenge) FROM Film GROUP BY StudioName"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# A Band Apart 154
# A24 233
# Disney 419
# Fox 113
# Littlestar Productions 108
# MGM 306
# Marvel Enterprises 121
# NULL 98
# Paramount  280
# Participant 135
# Pinewood 121
# Pixar 207
# River Road 134
# Scott Rudin Productions 95
# Summit Entertainment 128
# Village Roadshows  142
# Warner Bros. 152

# %% [markdown]
# ■ In SELECT-Klausel zwei „Sorten“ von Attributen
# <br>
# 1. Gruppierungsattribute
# <br>
# 2. Aggregierte Attribute
# <br>
# □ Nicht-aggregierte Werte der SELECT-Klausel müssen in der GROUP BY-Klausel erscheinen.
# <br>
# □ Keine der beiden Sorten muss erscheinen.

# %%
#SELECT StudioName 
#FROM Film 
#GROUP BY StudioName

__SQL__ = "SELECT StudioName FROM Film GROUP BY StudioName"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# A Band Apart
# A24
# Disney
# Fox
# Littlestar Productions
# MGM
# Marvel Enterprises
# NULL
# Paramount
# Participant
# Pinewood
# Pixar
# River Road
# Scott Rudin Productions
# Summit Entertainment
# Village Roadshows
# Warner Bros.

# %%
#SELECT SUM(Laenge) 
#FROM Film 
#GROUP BY StudioName

__SQL__ = "SELECT SUM(Laenge) FROM Film GROUP BY StudioName"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# 154
# 233
# 419
# 113
# 108
# 306
# 121
# 98
# 280
# 135
# 121
# 207
# 134
# 95
# 128
# 142
# 152

# %% [markdown]
# ■ Gruppierung bei Verwendung mehrerer Relationen wird am Schluss durchgeführt.

# %%
#SELECT Name, SUM(Laenge) 
#FROM ManagerIn, Film 
#WHERE ManagerinID = ProduzentinID 
#GROUP BY Name

__SQL__ = "SELECT Name, SUM(Laenge) FROM ManagerIn, Film WHERE ManagerinID = ProduzentinID GROUP BY Name"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Alan Bruckner 108
# Ann Sarnoff 121
# Bill Pohlad 280
# Bob Chapek 419
# Brian Robbins 134
# Daniel Katz 233
# Isaac Perlmutter 152
# Jim Berk 263
# Jim Morris 207
# Louis B.Mayer 306
# Paul Golding 121
# Quentin Tarantino 154
# Robert Kirby 142
# Scott Rudin 95
# Steve Asbell 113

# %% [markdown]
# ■ Reihenfolge der Ausführung (und des Lesens)
# <br>
# 1. FROM-Klausel
# <br>
# 2. WHERE-Klausel
# <br>
# 3. GROUP BY-Klausel
# <br>
# 4. SELECT-Klausel
# <br>
# <br>
# ■ Einschränkung der Ergebnismenge nach der Gruppierung durch HAVING

# %%
#SELECT Name, SUM(Laenge) 
#FROM ManagerIn, Film 
#WHERE ManagerinID = ProduzentinID 
#AND Gehalt > 1000000 GROUP BY Name

__SQL__ = "SELECT Name, SUM(Laenge) FROM ManagerIn, Film WHERE ManagerinID = ProduzentinID AND Gehalt > 1000000 GROUP BY Name"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Alan Bruckner 108
# Ann Sarnoff 121
# Bill Pohlad 280
# Bob Chapek 419
# Brian Robbins 134
# Daniel Katz 233
# Isaac Perlmutter 152
# Jim Berk 263
# Jim Morris 207
# Louis B.Mayer 306
# Paul Golding 121
# Quentin Tarantino 154
# Robert Kirby 142
# Scott Rudin 95
# Steve Asbell 113

# %%
#SELECT Name, SUM(Laenge) 
#FROM ManagerIn, Film 
#WHERE ManagerinID = ProduzentinID 
#GROUP BY Name HAVING SUM(Laenge) > 1000

__SQL__ = "SELECT Name, SUM(Laenge) FROM ManagerIn, Film WHERE ManagerinID = ProduzentinID GROUP BY Name HAVING SUM(Laenge) > 1000"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()

# %%
#SELECT Name 
#FROM ManagerIn, Film 
#WHERE ManagerinID = ProduzentinID 
#GROUP BY Name HAVING SUM(Laenge) > 1000

__SQL__ = "SELECT Name FROM ManagerIn, Film WHERE ManagerinID = ProduzentinID GROUP BY Name HAVING SUM(Laenge) > 1000"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()

# %% [markdown]
# ■ Aggregationen in HAVING-Klausel beziehen sich nur auf aktuelle Gruppe.
# <br>
# ■ Nur Gruppierungsattribute dürfen un-aggregiert in HAVING Klausel erscheinen (wie bei
# SELECT-Klausel).
# ### Zusammenfassung SQL
#  Grundbausteine einer SQL Anfrage (mit empfohlener Lesereihenfolge)
#  <br>
# □ 6. SELECT
# <br>
# □ 1. FROM
# <br>
# □ 2. WHERE
# <br>
# □ 3. GROUP BY
# <br>
# □ 4. HAVING
# <br>
# □ 5. ORDER BY
# <br><br>
# ■ SELECT … FROM … sind Pflicht.
# <br>
# □ Ausnahme: z.B. SELECT 7 + 3
# <br><br>
# ■ HAVING darf nur in Kombination mit GROUP BY erscheinen.

# %% [markdown]
# ## Datenbearbeitung(DML)
# ### Überblick
# ■  CRUD: Create, Read, Update, Delete
# <br><br>
# ■ Einfügen
# <br>
# □ INSERT INTO … VALUES…
# <br><br>
# ■ Löschen
# <br>
# □ DELETE FROM … WHERE …
# <br><br>
# ■ Ändern
# <br>
# □ UPDATE … SET … WHERE …
# ### Einfügen
# ■ Grundbaustein
# <br>
# □ INSERT INTO R(A1, …, An) VALUES (v1,…,vn);
# <br>
# □ Bei fehlenden Attributen
# <br>
# – Default-Wert aus Tabellendefinition (NULL, falls nicht anders angegeben)
# <br>
# □ Beispiel

# %%
# %sql INSERT INTO spielt_in(FilmTitel, FilmJahr, Schauspieler) VALUES (‘Star Wars‘, 1977, ‘Alec Guinness‘);

# %% [markdown]
# – Reihenfolge der Werte und Attribute wird beachtet.
#
# □ Falls alle Attribute gesetzt werden, kann Attributliste fehlen:

# %%
# %sql INSERT INTO spielt_in VALUES (‘Star Wars‘, 1977, ‘Alec Guinness‘);

# %% [markdown]
# – Reihenfolge entsprechend der Spezifikation des Schemas
# (CREATE TABLE …)
# #### Einfügen per Anfrage
#  Füge in Studio-Tabelle alle Studios der Filme-Relation ein
#  <br>
# □ Film(Titel, Jahr, Länge, inFarbe, StudioName, ProduzentinID)
#  <br>
# □ Studio(Name, Adresse, VorsitzendeID)

# %%
# %sql
INSERT INTO Studio(Name)
SELECT DISTINCT StudioName
FROM Film
WHERE StudioName NOT IN
    (SELECT Name
    FROM Studio);

# %% [markdown]
# Adresse und VorsitzendeIDbleiben NULL.
#  <br>
# □ Erzeugt im Allgemeinen Redundanz und sollte vermieden werden.
# ### Ausführungsreihenfolge beim Einfügen
# Wann wird eingefügt?
# <br>
# Nach vollständiger Ausführung der SELECT FROM WHERE Anfrage?
# <br>
# Sofort?
# <br>
# Schnellere Implementation
# <br>
# Was passiert jeweils bei Anfrage 1?
# <br>
# Was passiert jeweils bei Anfrage 2?
# <br>
# SQL Standard: Erst gesamte Anfrage ausführen

# %%
# %sql
INSERT INTO Studio(Name)
SELECT DISTINCT StudioName
FROM Film
WHERE StudioName NOT IN
    (SELECT Name
    FROM Studio);

# %%
# %sql
INSERT INTO Studio(Name)
SELECT StudioName
FROM Film
WHERE StudioName NOT IN
    (SELECT Name
    FROM Studio);

# %% [markdown]
# #### Bulk insert
#
# ■ INSERT
# <br>
# □ Zeilenbasiertes Einfügen aus SQL statements
# <br><br>
# ■ IMPORT
# <br>
# □ Zeilen-basiertes Einfügen aus Datei
# <br>
# □ Trigger und Nebenbedingungen bleiben aktiv
# <br>
# □ Indizes werden laufend aktualisiert
# <br><br>
# ■ LOAD
# <br>
# □ Seiten-basiertes Einfügen aus Datei
# <br>
# □ Trigger und Nebenbedingungen werden deaktiviert
# <br>
# □ Deutlich effizienter
# <br>
# □ Indizes werden am Ende neu generiert
# <br><br>
# ■ Syntax ist jeweils DBMS-spezifisch.
# <br>
# □ Viele Parameter
#
# ### Löschen
# ■ Grundbaustein
# <br>
# □ DELETE FROM R WHERE …
# <br>
# □ Lösche alle Tupel in R, für die die Bedingung wahr ist.

# %%
# %sql
DELETE FROM spielt_in
WHERE FilmTitel = ‘The Maltese Falcon‘
AND FilmJahr = 1942
AND Schauspieler = ‘Sydney Greenstreet‘;

# %% [markdown]
# ■ Tupel können im Gegensatz zum Einfügen nicht direkt angegeben werden, sondern müssen umschrieben werden.
# <br>

# %%
# %sql
DELETE FROM Manager
WHERE Gehalt < 10000000;

# %% [markdown]
# ■ Alle Manager-Tupel löschen: DELETE FROM Manager;
#
# ### Verändern (update)
# ■ Grundbaustein
# <br>
# □ UPDATE R SET … WHERE …
# <br>
# □ SET Klausel
# <br>
# – Wertzuweisungen
# <br>
# – Komma-separiert
# <br>

# %%
# %sql
UPDATE Manager
SET Name = ‘Präs. ‘ || Name
WHERE ManagerinID IN
(SELECT PräsidentID FROM Studios);

# %% [markdown]
# ## Schemata(DDL)
# ### Überblick
# ■ Datentypen
# <br>
# ■ Tabellen
# <br>
# ■ Default-Werte
# <br>
# ■ Indizes
#
# ### Datentypen
# ■ Jedes Attribut muss einen Datentyp haben.
# <br>
# □ CHAR(n) – String fester Länge (n Zeichen)
# <br>
# □ VARCHAR(n) – String variabler Länge, maximal n Zeichen
# <br>
# □ BIT(n) bzw. BIT VARYING(n) – Wie CHAR, aber Bits
# <br>
# □ BOOLEAN – TRUE, FALSE oder UNKNOWN
# <br>
# □ INT / INTEGER bzw. SHORTINT – 8 bzw. 4 Byte
# <br>
# □ FLOAT / REAL bzw. DOUBLE PRECISION
# <br>
# □ DECIMAL (n,d) – Z.B. Gehalt DECIMAL(7,2) – 7 Stellen, davon 2 Nachkommastellen
# <br>
# □ CLOB und BLOB
#
# ### Überblick DB2 Datentypen
# ![title](db2_datentypen.jpg)
#
# ### Tabellen
# ■ Grundbaustein zum Erzeugen

# %%
# %sql
CREATE TABLE R …
CREATE TABLE Schauspieler (
Name CHAR(30),
Adresse VARCHAR(255),
Geschlecht CHAR(1),
Geburtstag DATE );

# %% [markdown]
# ■ Löschen
# <br>
# □ DROP TABLE Schauspieler;
# <br><br>
# ■ Verändern
# <br>
# □ ALTER TABLE Schauspieler ADD Telefon CHAR(6);
# <br>
# – Nullwerte entstehen
# <br>
# □ ALTER TABLE Schauspieler DROP Geburtstag;
# <br>
# □ ALTER TABLE Schauspieler MODIFY Telefon CHAR(10);
#
# ### Default-Werte

# %%
# %sql
CREATE TABLE Schauspieler (
Name CHAR(30),
Adresse VARCHAR(255),
Geschlecht CHAR(1) DEFAULT ‚?‘,
Geburtstag DATE DEFAULT DATE ‚0000-00-00‘);

ALTER TABLE Schauspieler
ADD Telefon CHAR(16) DEFAULT ‚unbekannt‘;

# %% [markdown]
# ### Constraints und Trigger
#  Weitere Optionen für Tabellen
#  <br>
# □ PRIMARY KEY
#  <br>
# □ UNIQUE
#  <br>
# □ FOREIGN KEY … REFERENCES …
#  <br>
# □ NOT NULL
#  <br>
# □ CHECK
#  <br>
# □ CREATE ASSERTION
#  <br>
# □ CREATE TRIGGER
#  <br>
# ■ Siehe separater Foliensatz
#
# ### Indizes
# ■ Ein Index auf einem Attribut ist eine Datenstruktur, die es dem DBMS erleichtert, Tupel mit einem bekannten Wert des Attributs zu finden.
# <br>
# □ Nicht SQL-Standard, aber in (fast) jedem DBMS verfügbar.
# <br><br>
# ■ Motivation

# %%
#%sql SELECT * 
#FROM Film 
#WHERE StudioName = "Disney" 
#AND Jahr = 1990;

__SQL__ = "SELECT * FROM Film WHERE StudioName = 'Disney' AND Jahr = 1990"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Ducktales the Movie: Treasure of the Lost Lamp 1990 74 TRUE Disney 1234
# Shipwrecked 1990 92 TRUE Disney 1234
# The Rescuers Down Under 1990 77 TRUE Disney 1234

# %% [markdown]
# □ Variante 1: Alle 100.000 Tupel durchsuchen und WHERE Bedingung prüfen
# <br>
# □ Variante 2: Direkt alle 2000 Filme aus 1990 betrachten und auf ‚Disney‘ prüfen.
# <br>
# – CREATE INDEX JahrIndex ON Film(Jahr);
# <br>
# □ Variante 3: Direkt alle 100 Filme aus 1990 von ‘Disney‘ holen.

# %%
# %sql
CREATE INDEX JahrStudioIndex
ON Film(Jahr, Studioname);

# %% [markdown]
# ■ Indizes auf einzelnen Attributen
# <br>
# □ CREATE INDEX JahrIndex ON Film(Jahr);
# <br><br>
# ■ Indizes auf mehreren Attributen

# %%
# %sql
CREATE INDEX JahrStudioIndex
ON Film(Jahr, Studioname);

# %% [markdown]
# □ Reihenfolge wichtig! Warum?
# <br><br>
# ■ Löschen
# <br>
# □ DROP INDEX JahrIndex;
#
# #### Indexwahl
# ■ Abwägung
# <br>
# □ Index beschleunigt Punkt- (und Bereichs-) Anfragen und Join-Anfragen erheblich.
# <br>
# □ Index verlangsamt das Einfügen, Löschen und Verändern von Tupeln der Relation.
# <br>
# – Index muss jeweils zusätzlich aktualisiert werden.
# <br>
# □ Indizes benötigen Speicherplatz.
# <br><br>
# ■ Wahl der besten Indizes ist eine der schwierigsten Aufgaben des Datenbankdesigns.
# <br>
# □ Vorhersage der query workload und update-Frequenz
# <br>
# □ Wahl der Attribute
# <br>
# – Häufiger Vergleich mit Konstanten
# <br>
# – Häufiges Joinattribut
#
# #### Indexwahl – Vorüberlegungen
# ■ Relationen sind typischerweise über mehrere Diskblöcke gespeichert.
# <br>
# □ Wichtigste Datenbankkosten sind die Anzahl der Diskblöcke, die in den Hauptspeicher gelesen werden müssen.
# <br>
# □ Bei Punktanfragen mit Index müssen statt aller Blöcke nur ein Block gelesen werden.
# <br>
# □ Aber Index selbst muss ebenfalls gespeichert und gelesen werden.
# <br>
# – IdR viel mehr Tupel pro Block repräsentiert: Nur Schlüsselwert und Speicheradresse, keine Daten
# <br>
# □ Updates kosten sogar doppelt: Lesen und Schreiben auch der Index-Blöcke
#
# #### Indexwahl – Beispiel
# ■ spielt_in(FilmTitel, FilmJahr, Schauspieler)
# <br><br>
# ■ Drei typische Anfragen

# %%
#%sql SELECT FilmTitel, FilmJahr 
#FROM spielt_in WHERE Name = s;

__SQL__ = "SELECT FilmTitel, FilmJahr FROM spielt_in WHERE Name = s"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [88], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: no such column: s

# %%
# %sql
SELECT Schauspieler FROM spielt_in
WHERE FilmTitel = t AND FilmJahr = j;
INSERT INTO spielt_in VALUES(t, j, s);

# %% [markdown]
# ■ Annahmen
# <br>
# □ spielt_in ist auf 10 Disk-Blöcke verteilt.
# <br>
# □ Durchschnittlich habe jeder Film 3 Schauspieler.
# <br>
# □ Durchschnittlich spiele jeder Schauspieler in 3 Filmen.
# <br>
# □ Annahme des Schlimmsten: 3 Tupel sind auf 3 Blöcke verteilt
# <br>
# □ Index ist auf 1 Block gespeichert.
# <br>
# □ Lesen und Schreiben kostet 1.
# <br>
# □ Update und Insert kosten jeweils 2.
#
# #### Indexwahl – Beispiel
#
# |Anfrage|Kein Index|SchauspielerIndex|FilmIndex|Beide Indizes|
# |---|---|---|---|---|
# |**Schauspieler = s**|10|4|10|4|
# |**FilmTitel = t AND FilmJahr = j**|10|10|4|4|
# |**INSERT INTO spielt_in**|2|4|4|6|
# |**Gesamtkosten**|2+8$p_1$8$p_2$|4+6$p_2$|4+6$p_1$|6-2$p_1$-2$p_2$|
#
#
# ■ p1: Anteil Anfrage 1
# <br>
# ■ p2: Anteil Anfrage 2
# <br>
# ■ 1‒p1‒p2: Anteil Anfrage 3
# <br>
#
#
# ### Verteilung in IMDB (Real-world Daten, Stand ca. 2010)
# ![title](imdb.jpg)

# %%
# %sql
WITH
m AS (SELECT count(*) AS ZahlMovies FROM imdb.movie),
actress AS (SELECT count(*) AS ZahlActress FROM imdb.actress),
actor AS (SELECT count(*) AS ZahlActor FROM imdb.actor),
actors AS (SELECT (ZahlActress + ZahlActor) AS GesamtActors
FROM actress, actor)
SELECT DOUBLE(actors.GesamtActors) / DOUBLE(m.ZahlMovies)
FROM m, actors

# %% [markdown]
# Schauspieler*in pro Spielfilm: 8,7

# %%
# %sql
WITH
actors AS (SELECT * FROM imdb.actor UNION
SELECT * FROM imdb.actress),
counts AS (SELECT name, count(movie_id) AS m
FROM actors GROUP BY name)
SELECT AVG(DOUBLE(m)) FROM counts

# %% [markdown]
# Spielfilme pro Schauspieler: 4,2

# %% [markdown]
# ## Sichten
# ### Virtuelle Relationen
#
# ■ Relationen aus CREATE TABLE Ausdrücken existieren tatsächlich (materialisiert, physisch) in der Datenbank.
# <br>
# □ Persistenz
# <br>
# □ Updates sind möglich
# <br><br>
# ■ Die Daten aus Sichten (views) existieren nur virtuell.
# <br>
# □ Sichten entsprechen Anfragen, denen man einen Namen gibt. Sie wirken wie physische Relationen.
# <br>
# □ Updates sind nur manchmal möglich.
# <br>
# <br>
# ![title](stonebraker1.jpg)
# <br>
# ![title](stonebraker2.jpg)
# <br>
# Michael Stonebraker: Implementation of Integrity Constraints and Views by Query Modification. SIGMOD Conference 1975: 65-78
#
# ### Sichten in SQL
# ■ CREATE VIEW Name AS Anfrage

# %%
# %sql
CREATE VIEW ParamountFilme AS
SELECT Titel, Jahr
FROM Film
WHERE StudioName = "Paramount";

# %% [markdown]
# □ Auch mehr als eine Relation möglich!
# <br><br>
# ■ Bedeutung einer Anfrage an die Sicht
# <br>
# 1. Ausführung der Anfrage aus der Sichdefinition
# <br>
# 2. Die ursprüngliche Anfrage verwendet dann das Ergebnis als Relation.
# <br><br>
# ■ Daten der Sicht ändern sich mit der Änderung der zugrundeliegenden Relationen.
# <br>
# ■ Entfernen der Sicht: DROP VIEW ParamountFilme
# <br>
# □ Basisdaten bleiben unverändert.
#
# ### Anfragen an Sichten

# %%
# %sql
CREATE VIEW ParamountFilme AS
SELECT Titel, Jahr
FROM Film
WHERE StudioName = "Paramount";

# %%
# %sql
SELECT Titel
FROM ParamountFilme
WHERE Jahr = 1979;

# %% [markdown]
# ■ Umwandlung der ursprünglichen Anfrage in eine Anfrage an Basisrelationen

# %%
#SELECT Titel 
#FROM Film 
#WHERE StudioName = "Paramount" 
#AND Jahr = 1979;

__SQL__ = "SELECT Titel FROM Film WHERE StudioName = 'Paramount' AND Jahr = 1979;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()

# %% [markdown]
# □ Übersetzung durch DBMS
# <br>
# ■ Anfrage zugleich an Sichten und Basisrelationen möglich

# %%
#Anfrage aus VL Folien
#SELECT DISTINCT SchauspielerIn
#FROM ParamountFilme, spielt_in
#WHERE Titel = FilmTitel AND Jahr = FilmJahr;

#Anfrage für filme.db
__SQL__ = "SELECT DISTINCT Name FROM Film, spielt_in WHERE Titel = FilmTitel AND Jahr = FilmJahr;"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Mark Hamill
# Harrison Ford
# Carrie Fisher
# Emile Hirsch
# Jake Gyllenhaal
# Heath Ledger
# Robert Pattinson
# Willem Dafoe
# Leonardo DiCaprio
# Tobey Maguire
# Carey Mulligan
# Saoirse Ronan
# Vincent Cassel
# Meryl Streep
# Phyllis Smith
# Arnold Schwarzenegger
# Sharon Stone
# Samuel L. Jackson
# Tom Hanks
# Kirsten Dunst
# Emma Stone
# Ryan Gosling
# Mahershala Ali
# William Shatner
# Alan Young
# Jared Leto
# Adam Driver
# Lady Gaga
# Daniel Craig
# Léa Seydoux
# Christoph Waltz

# %% [markdown]
# ■ Film(Titel, Jahr, Länge, inFarbe, StudioName, ProduzentinID)
# ■ Manager(Name, Adresse, ManagerinID, Gehalt)

# %%
# %sql
CREATE VIEW FilmeProduzenten AS
    SELECT Titel, Name
    FROM Film, Manager
    WHERE ProduzentinID = ManagerinID;

# %% [markdown]
# ■ Anfrage

# %%
#%sql SELECT Name FROM FilmeProduzenten WHERE Titel = ‘Gone with the Wind‘

__SQL__ = "SELECT Name FROM FilmeProduzenten WHERE Titel = 'Gone with the Wind'"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [93], in <cell line: 6>()
#       4 conn = sqlite3.connect("filme/filme.db")
#       5 cur = conn.cursor()
# ----> 6 cur.execute(__SQL__)
#       7 rows = cur.fetchall()
#       9 for row in rows:
#
# OperationalError: no such table: FilmeProduzenten

# %% [markdown]
# ■ Bedeutung

# %%
#%sql SELECT Name FROM Film, ManagerIn WHERE ProduzentinID = ManagerinID AND Titel = 'Gone with the Wind';

__SQL__ = "SELECT Name FROM Film, ManagerIn WHERE ProduzentinID = ManagerinID AND Titel = 'Gone with the Wind';"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()

# %% [markdown]
# ■ Nebenbei: Umbenennung von Attributen

# %%
# %sql
CREATE VIEW FilmeProduzenten(FilmTitel, Produzentenname) AS
SELECT Titel, Name
FROM Film, ManagerIn
WHERE ProduzentinID = ManagerinID;

# %% [markdown]
# ■ Oder auch: Sicht einfach nur zur Umbenennung

# %%
# %sql
CREATE VIEW Movie(title, year, length, inColor, studio, producerID) AS
SELECT *
FROM Film;

# %% [markdown]
# ### Diskussion
# ■ Vorteile
# <br>
# □ Vereinfachung von Anfragen
# <br>
# □ Strukturierung der Datenbank
# <br>
# □ Logische Datenunabhängigkeit
# <br>
# – Sichten stabil bei Änderungen der Datenbankstruktur
# <br>
# – Sichtdefinitionen müssen gegebenenfalls angepasst werden
# <br>
# – Stabilität nicht bei jeder Änderung
# <br>
# □ Beschränkung von Zugriffen (Datenschutz)
# <br>
# □ Optimierung durch materialisierte Sichten
# <br><br>
# ■ Probleme
# <br>
# □ Automatische Anfragetransformation schwierig
# <br>
# □ Änderungen auf Sichten
# <br>
# □ Updatepropagierung für materialisierte Sichten
#
# ### Updates auf Sichten
# ■ In einigen Fällen ist es möglich, Einfüge-, Lösch- oder Updateoperationen auf Sichten durchzuführen.
# <br>
# □ Wo speichern?
# <br>
# □ Welche Relation?
# <br>
# □ Zuordnung der Änderung zur Sicht?
# <br><br>
# ■ Übersetzung der Update-Operation auf eine Update-Operation der zugrunde liegenden Basisrelationen
# <br>
# □ Nur bei einer Relation
# <br>
# – Keine Subanfragen mit Selbstbezug
# <br>
# □ Nur bei normalem SELECT
# <br>
# – Kein DISTINCT
# <br>
# □ Nur falls genug Attribute verwendet werden, so dass alle anderen Attribute mit NULL oder dem Default-Wert gefüllt werden können.
#
# ### Einfügen auf Sichten – Beispiel
# ■ Filme(Titel, Jahr, Länge, inFarbe, StudioName, ProduzentinID)

# %%
# %sql
CREATE VIEW ParamountFilme AS
    SELECT Titel, Jahr
    FROM Filme
    WHERE StudioName = ‚Paramount‘;

# %%
# %sql
INSERT INTO ParamountFilme
VALUES (‚Star Trek‘, 1979);

# %% [markdown]
# □ Wert für Studioname?
# □ Einfügen also nicht erlaubt.

# %%
# %sql
CREATE VIEW ParamountFilme AS
    SELECT Titel, Jahr, StudioName
    FROM Filme
    WHERE StudioName = ‚Paramount‘;

# %%
# %sql
INSERT INTO ParamountFilme
VALUES (‚Star Trek‘, 1979, ‚Paramount‘);

# %% [markdown]
# Dies muss Paramount sein. Ein anderes Studio entspricht nicht der View.
# <br><br>
# ■ Neues Tupel (‚Star Trek‘, 1979, 0, NULL, ‚Paramount‘, NULL)
#
# ### Löschen und Updates auf Sichten
# ■ Löschen

# %%
# %sql
DELETE FROM ParamountFilme
WHERE Titel LIKE ‚%Trek%‘;

# %% [markdown]
# ■ Wird umgeschrieben zu

# %%
# %sql
DELETE FROM Filme
WHERE Titel LIKE ‚%Trek%‘ AND StudioName = ‚Paramount‘;

# %% [markdown]
# ■ Update

# %%
# %sql
UPDATE ParamountFilme
SET Jahr = 1979
WHERE Titel = ‚Star Trek the Movie‘;

# %% [markdown]
# ■ Wird zu

# %%
# %sql
UPDATE Filme
SET Jahr = 1979
WHERE Titel = ‚Star Trek the Movie‘ AND StudioName = ‚Paramount‘;

# %% [markdown]
# ### Tupelmigration
# ■ Manager(Name, Adresse, ManagerinID, Gehalt)

# %%
# %sql
CREATE VIEW Reiche AS
    SELECT Name, Gehalt, ManagerinID
    FROM ManagerIn
    WHERE Gehalt > 2000000;

# %% [markdown]
# ■ Tupelmigration:
# <br>
# □ Ein Tupel (‚Eisner\`, ‚Hollywood‘, 25, 3000000) wird aus der Sicht „herausbewegt“.

# %%
# %sql
UPDATE Reiche SET Gehalt = 1500000
WHERE ManagerinID = 25;

# %% [markdown]
# ■ Vorsicht bei der Implementierung, oder explizite Verhinderung:

# %%
# %sql
CREATE VIEW Reiche AS
SELECT Name, Gehalt
FROM ManagerIn
WHERE Gehalt > 2000000
WITH CHECK OPTION;

# %% [markdown]
# □ Verhindert Tupelmigration durch Ablehnung problematischer Updates.
#
# ### Anfrageplanung mit Sichten
# ■ Baumdarstellung von Anfragen
# <br>
# □ Blätter repräsentieren Relationen
# <br>
# – Basisrelationen
# <br>
# – Sichten
# <br>
# □ Ersetzung der Sichten durch die Sichtdefinition
# <br>
# – Als Subanfrage
# <br>
# ![title](anfrageplanung1.jpg)
# <br><br>
# ■ Sicht

# %%
# %sql
CREATE VIEW ParamountFilme AS
SELECT Titel, Jahr
FROM Filme
WHERE StudioName = ‚Paramount‘;

# %% [markdown]
# ■ Anfrage

# %%
#Anfrage aus VL Folien
#SELECT Titel 
#FROM ParamountFilme 
#WHERE Jahr = 1979;

#Neue Anfrage für filme.db
__SQL__ = "SELECT Titel FROM Film WHERE Jahr = 1979"
conn = sqlite3.connect("filme/filme.db")
cur = conn.cursor()
cur.execute(__SQL__)
rows = cur.fetchall()

for row in rows:
    for col in row:
        print(col,end=' ')
    print()
# Out:
# Star Trek

# %% [markdown]
# ![title](anfrageplanung2.jpg)
# <br>
# ![title](anfrageplanung3.jpg)
# <br>
# ![title](anfrageplanung4.jpg)
#
# ### Materialisierte Sichten
# ■ Viele Anfragen an eine Datenbank wiederholen sich häufig
# <br>
# □ Business Reports, Bilanzen, Umsätze
# <br>
# □ Bestellungsplanung, Produktionsplanung
# <br>
# □ Kennzahlenberechnung
# <br><br>
# ■ Viele Anfragen sind Variationen mit gemeinsamem Kern
# <br><br>
# ■ Idee: Einmaliges Berechnen der Anfrage als Sicht
# <br>
# □ Automatische, transparente Verwendung in folgenden Anfragen
# <br>
# □ Materialisierte Sicht (materialized view, MV)
# <br>
# Drei Folien nach Prof. Ulf Leser, HU Berlin
#
# #### MV – Themen und Probleme
# ■ Wahl von Views zur Materialisierung
# <br>
# □ MVs kosten: Platz und Aktualisierungsaufwand
# <br>
# □ Wahl der optimalen MVs hängt von Workload ab
# <br>
# □ Auswahl der „optimalen“ Menge von MVs
# <br><br>
# ■ Automatische Aktualisierung von MVs
# <br>
# □ Aktualisierung bei Änderungen der Basisrelationen
# <br>
# □ U.U. schwierig: Aggregate, Joins, Outer-Joins, ...
# <br>
# □ Algorithmen zur inkrementellen Aktualisierung
# <br><br>
# ■ Automatische Verwendung von MV
# <br>
# □ „Answering Queries using Views“
# <br>
# □ Umschreiben der Anfrage notwendig
# <br>
# □ Schwierigkeit hängt von Komplexität der Anfrage / Views ab
# <br>
# □ Algorithmen zur transparenten und kostenoptimalen Verwendung der materialisierten Sichten
#
# ### „Answering Queries using Views“
# ■ Gegeben
# <br>
# □ Eine Anfrage Q
# <br>
# □ Eine Menge V (materialisierten) von Sichten
# <br><br>
# ■ Fragen
# <br>
# □ Kann man Q überhaupt unter Verwendung von V beantworten?
# <br>
# □ Kann man Q nur mit V beantworten?
# <br>
# □ Kann man Q mit V vollständig beantworten?
# <br>
# □ Ist es günstig, Sichten aus V zur Beantwortung von Q zu verwenden? Welche?
#
# ## Zusammenfassung
# Die Anfragesprache SQL
# <br>
# Der SFW Block
# <br>
# Subanfragen
# <br>
# In FROM und WHERE
# <br>
# EXISTS, IN, ALL, ANY
# <br>
# Mengenoperationen
# <br>
# UNION, INTERSECT, EXCEPT
# <br>
# Joins und Outerjoins
# <br>
# Nullwerte
# <br>
# Mengen vs. Multimengen
# <br>
# DISTINCT, ALL
# <br>
# Gruppierung und Aggregation
# <br>
# MIN, MAX, COUNT
# <br>
# GROUP BY, HAVING
# <br>
# Datenbankveränderungen
# <br>
# INSERT, UPDATE, DELETE
# <br>
# Schemata und Datentypen
# <br>
# CREATE TABLE
# <br>
# ALTER TABLE
# <br>
# Indizes
# <br>
# Sichten
# <br>
# Anfragen (und updates)
# <br>
# Materialisierte Sichten
