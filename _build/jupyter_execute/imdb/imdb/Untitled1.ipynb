# %% [markdown]
# # sql test

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ipython-sql
# Out:
# ...
#      |                                | 10 kB 1.1 MB/s eta 0:00:06
#      |▎                               | 61 kB 830 kB/s eta 0:00:08
#      |██                              | 358 kB 1.1 MB/s eta 0:00:05
#      |███▌                            | 645 kB 1.1 MB/s eta 0:00:05
#      |██████                          | 1.1 MB 1.1 MB/s eta 0:00:05
#      |████████▉                       | 1.6 MB 1.1 MB/s eta 0:00:04
#      |████████████▍                   | 2.3 MB 1.1 MB/s eta 0:00:04
#      |███████████████▏                | 2.8 MB 1.1 MB/s eta 0:00:03
#      |██████████████████▊             | 3.5 MB 1.1 MB/s eta 0:00:03
#      |█████████████████████▎          | 4.0 MB 1.1 MB/s eta 0:00:02
#      |████████████████████████▉       | 4.6 MB 1.1 MB/s eta 0:00:02
#      |███████████████████████████▌    | 5.1 MB 1.1 MB/s eta 0:00:01
#      |███████████████████████████████▎| 5.8 MB 1.1 MB/s eta 0:00:01
#      |████████████████████████████████| 6.0 MB 1.1 MB/s
# ...
# \
# |
# /
# -
# \
# |
# /
# ...

# %%
import sys
sys.executable
# Out:
# '/Users/abedjan/opt/anaconda3/bin/python'

# %%
# %load_ext sql
# %sql sqlite:///imdb.db

# %%
# %sql SELECT name FROM actor WHERE name LIKE '%Krug%'
# Out:
#  * sqlite:///imdb.db
# Done.
# [('Krug, Manfred',), ('Krug, Manfred',), ('Krug, Manfred',)]
